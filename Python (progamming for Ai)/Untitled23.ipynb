# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
webpage = requests.get("https://content.codecademy.com/courses/beautifulsoup/cacao/index.html")
print(webpage.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#    <head>
#       <meta charset="utf-8">
#       <style>
#          #cacaoTable {
#          border-collapse: collapse;
#          border: 2px black solid;
#          font: 12px sans-serif;
#          }
#          #cacaoTable td {
#          border: 1px black solid;
#          padding: 5px;
#          }
#          #infoContainer {
#          margin-bottom: 10px;
#          display: inline-block;
#          margin-right: 10px;
#          }
#          #chocolate {
#          width: 300px;
#          }
#          #picContainer {
#          display: inline;
#          }
#       </style>
#    </head>
#    <body>
#       <!-- <script src="http://d3js.org/d3.v3.min.js"></script> -->
#       <div id="banner">
#          <h1>Cacao Ratings</h1>
#       </div>
#       <div id="infoContainer">
#          <table class="infoTable">
#             <tr>
#                <td>Compiled ratings of over 1700 Chocolate bars</td>
#             </tr>
#             <tr>
#                <td>Ratings are from 1-5</td>
#             </tr>
#          </table>
#       </div>
#       <div id="picContainer">
#          <img id="chocolate" src="chocolate.jpg">
#       </div>
#       <table id="cacaoTable">
#          <tr>
#             <td class="Company">Company&nbsp;
#                (Maker-if known)
#             </td>
#             <td class="Origin">Specific Bean Origin
#                or Bar Name
#             </td>
#             <td class="REF">REF</td>
#             <td class="ReviewDate">Review
#                Date
#             </td>
#             <td class="CocoaPercent">Cocoa
#                Percent
#             </td>
#             <td class="CompanyLocation">Company
#                Location
#             </td>
#             <td class="Rating">Rating</td>
#             <td class="BeanType">Bean
#                Type
#             </td>
#             <td class="BroadBeanOrigin">Broad Bean
#                Origin
#             </td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Agua Grande</td>
#             <td class="REF">1876</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">63%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Sao Tome</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Kpime</td>
#             <td class="REF">1676</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Togo</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Atsane</td>
#             <td class="REF">1676</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Togo</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Akata</td>
#             <td class="REF">1680</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Togo</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Quilla</td>
#             <td class="REF">1704</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Carenero</td>
#             <td class="REF">1315</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Cuba</td>
#             <td class="REF">1315</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Cuba</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Sur del Lago</td>
#             <td class="REF">1315</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Puerto Cabello</td>
#             <td class="REF">1319</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Pablino</td>
#             <td class="REF">1319</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Panama</td>
#             <td class="REF">1011</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Panama</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Madagascar</td>
#             <td class="REF">1011</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Brazil</td>
#             <td class="REF">1011</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Equateur</td>
#             <td class="REF">1011</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Colombie</td>
#             <td class="REF">1015</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Colombia</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Birmanie</td>
#             <td class="REF">1015</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Burma</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Papua New Guinea</td>
#             <td class="REF">1015</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Papua New Guinea</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Chuao</td>
#             <td class="REF">1015</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Piura</td>
#             <td class="REF">1019</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Chanchamayo Province</td>
#             <td class="REF">1019</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Chanchamayo Province</td>
#             <td class="REF">1019</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">63%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Bolivia</td>
#             <td class="REF">797</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">A. Morin</td>
#             <td class="Origin">Peru</td>
#             <td class="REF">797</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">63%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Acalli</td>
#             <td class="Origin">Chulucanas, El Platanal</td>
#             <td class="REF">1462</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Acalli</td>
#             <td class="Origin">Tumbes, Norandino</td>
#             <td class="REF">1470</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Adi</td>
#             <td class="Origin">Vanua Levu</td>
#             <td class="REF">705</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">Fiji</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Fiji</td>
#          </tr>
#          <tr>
#             <td class="Company">Adi</td>
#             <td class="Origin">Vanua Levu, Toto-A</td>
#             <td class="REF">705</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">80%</td>
#             <td class="CompanyLocation">Fiji</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Fiji</td>
#          </tr>
#          <tr>
#             <td class="Company">Adi</td>
#             <td class="Origin">Vanua Levu</td>
#             <td class="REF">705</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">88%</td>
#             <td class="CompanyLocation">Fiji</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Fiji</td>
#          </tr>
#          <tr>
#             <td class="Company">Adi</td>
#             <td class="Origin">Vanua Levu, Ami-Ami-CA</td>
#             <td class="REF">705</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">72%</td>
#             <td class="CompanyLocation">Fiji</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Fiji</td>
#          </tr>
#          <tr>
#             <td class="Company">Aequare (Gianduja)</td>
#             <td class="Origin">Los Rios, Quevedo, Arriba</td>
#             <td class="REF">370</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">55%</td>
#             <td class="CompanyLocation">Ecuador</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Forastero (Arriba)</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Aequare (Gianduja)</td>
#             <td class="Origin">Los Rios, Quevedo, Arriba</td>
#             <td class="REF">370</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Ecuador</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Forastero (Arriba)</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Ah Cacao</td>
#             <td class="Origin">Tabasco</td>
#             <td class="REF">316</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Mexico</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Mexico</td>
#          </tr>
#          <tr>
#             <td class="Company">Akesson's (Pralus)</td>
#             <td class="Origin">Bali (west), Sukrama Family, Melaya area</td>
#             <td class="REF">636</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Switzerland</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Indonesia</td>
#          </tr>
#          <tr>
#             <td class="Company">Akesson's (Pralus)</td>
#             <td class="Origin">Madagascar, Ambolikapiky P.</td>
#             <td class="REF">502</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Switzerland</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Akesson's (Pralus)</td>
#             <td class="Origin">Monte Alegre, D. Badero</td>
#             <td class="REF">508</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Switzerland</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">Alain Ducasse</td>
#             <td class="Origin">Trinite</td>
#             <td class="REF">1215</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">65%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Trinidad</td>
#          </tr>
#          <tr>
#             <td class="Company">Alain Ducasse</td>
#             <td class="Origin">Vietnam</td>
#             <td class="REF">1215</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Vietnam</td>
#          </tr>
#          <tr>
#             <td class="Company">Alain Ducasse</td>
#             <td class="Origin">Madagascar</td>
#             <td class="REF">1215</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Alain Ducasse</td>
#             <td class="Origin">Chuao</td>
#             <td class="REF">1061</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Alain Ducasse</td>
#             <td class="Origin">Piura, Perou</td>
#             <td class="REF">1173</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Alexandre</td>
#             <td class="Origin">Winak Coop, Napo</td>
#             <td class="REF">1944</td>
#             <td class="ReviewDate">2017</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Netherlands</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Forastero (Nacional)</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Alexandre</td>
#             <td class="Origin">La Dalia, Matagalpa</td>
#             <td class="REF">1944</td>
#             <td class="ReviewDate">2017</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Netherlands</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Criollo, Trinitario</td>
#             <td class="BroadBeanOrigin">Nicaragua</td>
#          </tr>
#          <tr>
#             <td class="Company">Alexandre</td>
#             <td class="Origin">Tien Giang</td>
#             <td class="REF">1944</td>
#             <td class="ReviewDate">2017</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Netherlands</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Vietnam</td>
#          </tr>
#          <tr>
#             <td class="Company">Alexandre</td>
#             <td class="Origin">Makwale Village, Kyela</td>
#             <td class="REF">1944</td>
#             <td class="ReviewDate">2017</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Netherlands</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">Tanzania</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Momotombo</td>
#             <td class="REF">1728</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Nicaragua</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Acopagro</td>
#             <td class="REF">1728</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">CIAAB Coop</td>
#             <td class="REF">1732</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">2.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Villa Andina</td>
#             <td class="REF">1732</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">2.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Gruppo Salinas</td>
#             <td class="REF">1732</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Sur del Lago</td>
#             <td class="REF">1125</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">2.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Conacado</td>
#             <td class="REF">1125</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Dominican Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Bolivia</td>
#             <td class="REF">1129</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">80%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Bolivia</td>
#             <td class="REF">1133</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Altus aka Cao Artisan</td>
#             <td class="Origin">Peru</td>
#             <td class="REF">1133</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Morobe</td>
#             <td class="REF">725</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Papua New Guinea</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Dos Rios</td>
#             <td class="REF">470</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Dominican Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Guayas</td>
#             <td class="REF">470</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Chuao</td>
#             <td class="REF">544</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Montanya</td>
#             <td class="REF">363</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Bali, Jembrana</td>
#             <td class="REF">304</td>
#             <td class="ReviewDate">2008</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Indonesia</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Madagascar</td>
#             <td class="REF">129</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Cuyagua</td>
#             <td class="REF">147</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amano</td>
#             <td class="Origin">Ocumare</td>
#             <td class="REF">175</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Criollo</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amatller (Simon Coll)</td>
#             <td class="Origin">Ghana</td>
#             <td class="REF">322</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Spain</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">Ghana</td>
#          </tr>
#          <tr>
#             <td class="Company">Amatller (Simon Coll)</td>
#             <td class="Origin">Ecuador</td>
#             <td class="REF">327</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Spain</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Amatller (Simon Coll)</td>
#             <td class="Origin">Ecuador</td>
#             <td class="REF">464</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">85%</td>
#             <td class="CompanyLocation">Spain</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Amatller (Simon Coll)</td>
#             <td class="Origin">Ghana</td>
#             <td class="REF">464</td>
#             <td class="ReviewDate">2009</td>
#             <td class="CocoaPercent">85%</td>
#             <td class="CompanyLocation">Spain</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">Ghana</td>
#          </tr>
#          <tr>
#             <td class="Company">Amazona</td>
#             <td class="Origin">LamasdelChanka, San Martin, Oro Verde coop</td>
#             <td class="REF">1145</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">72%</td>
#             <td class="CompanyLocation">Peru</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Amazona</td>
#             <td class="Origin">Bellavista Gran Pajeten, San Martin</td>
#             <td class="REF">1145</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">73%</td>
#             <td class="CompanyLocation">Peru</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Ambrosia</td>
#             <td class="Origin">Belize</td>
#             <td class="REF">1494</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">64%</td>
#             <td class="CompanyLocation">Canada</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Belize</td>
#          </tr>
#          <tr>
#             <td class="Company">Ambrosia</td>
#             <td class="Origin">Madagascar</td>
#             <td class="REF">1494</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">66%</td>
#             <td class="CompanyLocation">Canada</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Ambrosia</td>
#             <td class="Origin">Dominican Republic</td>
#             <td class="REF">1498</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Canada</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Dominican Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Ambrosia</td>
#             <td class="Origin">Papua New Guinea</td>
#             <td class="REF">1498</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">63%</td>
#             <td class="CompanyLocation">Canada</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Papua New Guinea</td>
#          </tr>
#          <tr>
#             <td class="Company">Ambrosia</td>
#             <td class="Origin">Venezuela</td>
#             <td class="REF">1498</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Canada</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Ambrosia</td>
#             <td class="Origin">Peru</td>
#             <td class="REF">1498</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">68%</td>
#             <td class="CompanyLocation">Canada</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Piura, Blanco de Criollo</td>
#             <td class="REF">979</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Porcelana</td>
#             <td class="REF">111</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">Criollo (Porcelana)</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Nine</td>
#             <td class="REF">111</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">Blend</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Chuao</td>
#             <td class="REF">111</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Ecuador</td>
#             <td class="REF">123</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Jamaica</td>
#             <td class="REF">123</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Jamaica</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Grenada</td>
#             <td class="REF">123</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Grenada</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Venezuela</td>
#             <td class="REF">123</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Trinitario (85% Criollo)</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Madagascar</td>
#             <td class="REF">123</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">Trinitario (85% Criollo)</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Trinidad</td>
#             <td class="REF">129</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Trinidad</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Toscano Black</td>
#             <td class="REF">170</td>
#             <td class="ReviewDate">2007</td>
#             <td class="CocoaPercent">63%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Blend</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Toscano Black</td>
#             <td class="REF">40</td>
#             <td class="ReviewDate">2006</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">5</td>
#             <td class="BeanType">Blend</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Amedei</td>
#             <td class="Origin">Toscano Black</td>
#             <td class="REF">75</td>
#             <td class="ReviewDate">2006</td>
#             <td class="CocoaPercent">66%</td>
#             <td class="CompanyLocation">Italy</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">Blend</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">AMMA</td>
#             <td class="Origin">Catongo</td>
#             <td class="REF">1065</td>
#             <td class="ReviewDate">2013</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Brazil</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">Forastero (Catongo)</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">AMMA</td>
#             <td class="Origin">Monte Alegre, 3 diff. plantations</td>
#             <td class="REF">572</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">85%</td>
#             <td class="CompanyLocation">Brazil</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Forastero (Parazinho)</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">AMMA</td>
#             <td class="Origin">Monte Alegre, 3 diff. plantations</td>
#             <td class="REF">572</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">50%</td>
#             <td class="CompanyLocation">Brazil</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Forastero (Parazinho)</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">AMMA</td>
#             <td class="Origin">Monte Alegre, 3 diff. plantations</td>
#             <td class="REF">572</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Brazil</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">Forastero (Parazinho)</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">AMMA</td>
#             <td class="Origin">Monte Alegre, 3 diff. plantations</td>
#             <td class="REF">572</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">Brazil</td>
#             <td class="Rating">4</td>
#             <td class="BeanType">Forastero (Parazinho)</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#          <tr>
#             <td class="Company">Anahata</td>
#             <td class="Origin">Elvesia</td>
#             <td class="REF">1259</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Dominican Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Animas</td>
#             <td class="Origin">Alto Beni</td>
#             <td class="REF">1852</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Ara</td>
#             <td class="Origin">Madagascar</td>
#             <td class="REF">1375</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Ara</td>
#             <td class="Origin">Chiapas</td>
#             <td class="REF">1379</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">72%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Mexico</td>
#          </tr>
#          <tr>
#             <td class="Company">Ara</td>
#             <td class="Origin">Equateur</td>
#             <td class="REF">1379</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Ara</td>
#             <td class="Origin">Trincheras</td>
#             <td class="REF">1379</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">France</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Venezuela</td>
#          </tr>
#          <tr>
#             <td class="Company">Arete</td>
#             <td class="Origin">San Juan</td>
#             <td class="REF">1724</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Trinidad</td>
#          </tr>
#          <tr>
#             <td class="Company">Arete</td>
#             <td class="Origin">Kokoa Kamili</td>
#             <td class="REF">1724</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Tanzania</td>
#          </tr>
#          <tr>
#             <td class="Company">Arete</td>
#             <td class="Origin">Tien Giang</td>
#             <td class="REF">1900</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">73%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Vietnam</td>
#          </tr>
#          <tr>
#             <td class="Company">Arete</td>
#             <td class="Origin">Hacienda Victoria</td>
#             <td class="REF">1904</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Arete</td>
# ...
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Domincan Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Zak's</td>
#             <td class="Origin">Madagascar, Batch 2</td>
#             <td class="REF">1578</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Zak's</td>
#             <td class="Origin">Peru, Batch 1</td>
#             <td class="REF">1578</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Zak's</td>
#             <td class="Origin">Belize, Batch 2</td>
#             <td class="REF">1578</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Belize</td>
#          </tr>
#          <tr>
#             <td class="Company">Zak's</td>
#             <td class="Origin">House Blend, Batch 2</td>
#             <td class="REF">1582</td>
#             <td class="ReviewDate">2015</td>
#             <td class="CocoaPercent">60%</td>
#             <td class="CompanyLocation">U.S.A.</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Zart Pralinen</td>
#             <td class="Origin">Millot P., Ambanja</td>
#             <td class="REF">1820</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Criollo, Trinitario</td>
#             <td class="BroadBeanOrigin">Madagascar</td>
#          </tr>
#          <tr>
#             <td class="Company">Zart Pralinen</td>
#             <td class="Origin">UNOCACE</td>
#             <td class="REF">1824</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Nacional (Arriba)</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Zart Pralinen</td>
#             <td class="Origin">San Juan Estate</td>
#             <td class="REF">1824</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">85%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Trinidad</td>
#          </tr>
#          <tr>
#             <td class="Company">Zart Pralinen</td>
#             <td class="Origin">Kakao Kamili, Kilombero Valley</td>
#             <td class="REF">1824</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">85%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Criollo, Trinitario</td>
#             <td class="BroadBeanOrigin">Tanzania</td>
#          </tr>
#          <tr>
#             <td class="Company">Zart Pralinen</td>
#             <td class="Origin">Kakao Kamili, Kilombero Valley</td>
#             <td class="REF">1824</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Criollo, Trinitario</td>
#             <td class="BroadBeanOrigin">Tanzania</td>
#          </tr>
#          <tr>
#             <td class="Company">Zart Pralinen</td>
#             <td class="Origin">San Juan Estate, Gran Couva</td>
#             <td class="REF">1880</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">78%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Trinidad</td>
#          </tr>
#          <tr>
#             <td class="Company">Zokoko</td>
#             <td class="Origin">Guadalcanal</td>
#             <td class="REF">1716</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">78%</td>
#             <td class="CompanyLocation">Australia</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Solomon Islands</td>
#          </tr>
#          <tr>
#             <td class="Company">Zokoko</td>
#             <td class="Origin">Goddess Blend</td>
#             <td class="REF">1780</td>
#             <td class="ReviewDate">2016</td>
#             <td class="CocoaPercent">65%</td>
#             <td class="CompanyLocation">Australia</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Zokoko</td>
#             <td class="Origin">Alto Beni</td>
#             <td class="REF">697</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">68%</td>
#             <td class="CompanyLocation">Australia</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Zokoko</td>
#             <td class="Origin">Tokiala</td>
#             <td class="REF">701</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">66%</td>
#             <td class="CompanyLocation">Australia</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Trinitario</td>
#             <td class="BroadBeanOrigin">Papua New Guinea</td>
#          </tr>
#          <tr>
#             <td class="Company">Zokoko</td>
#             <td class="Origin">Tranquilidad, Baures</td>
#             <td class="REF">701</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">72%</td>
#             <td class="CompanyLocation">Australia</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Raw</td>
#             <td class="REF">1205</td>
#             <td class="ReviewDate">2014</td>
#             <td class="CocoaPercent">80%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">2.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Bocas del Toro, Cocabo Co-op</td>
#             <td class="REF">801</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">72%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Panama</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Amazonas Frucht</td>
#             <td class="REF">801</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">65%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Satipo Pangoa region, 16hr conche</td>
#             <td class="REF">875</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Criollo (Amarru)</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Satipo Pangoa region, 20hr conche</td>
#             <td class="REF">875</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Criollo (Amarru)</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Loma Los Pinos, Yacao region, D.R.</td>
#             <td class="REF">875</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">62%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Dominican Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">El Oro</td>
#             <td class="REF">879</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Forastero (Nacional)</td>
#             <td class="BroadBeanOrigin">Ecuador</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Huiwani Coop</td>
#             <td class="REF">879</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">75%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Criollo, Trinitario</td>
#             <td class="BroadBeanOrigin">Papua New Guinea</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">El Ceibo Coop</td>
#             <td class="REF">879</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">90%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Bolivia</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Santo Domingo</td>
#             <td class="REF">879</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Dominican Republic</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Kongo, Highlands</td>
#             <td class="REF">883</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">68%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">Congo</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Indianer, Raw</td>
#             <td class="REF">883</td>
#             <td class="ReviewDate">2012</td>
#             <td class="CocoaPercent">58%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">&nbsp;</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Peru</td>
#             <td class="REF">647</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">70%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.75</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Peru</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Congo</td>
#             <td class="REF">749</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">65%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">Congo</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Kerala State</td>
#             <td class="REF">749</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">65%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.5</td>
#             <td class="BeanType">Forastero</td>
#             <td class="BroadBeanOrigin">India</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Kerala State</td>
#             <td class="REF">781</td>
#             <td class="ReviewDate">2011</td>
#             <td class="CocoaPercent">62%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3.25</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">India</td>
#          </tr>
#          <tr>
#             <td class="Company">Zotter</td>
#             <td class="Origin">Brazil, Mitzi Blue</td>
#             <td class="REF">486</td>
#             <td class="ReviewDate">2010</td>
#             <td class="CocoaPercent">65%</td>
#             <td class="CompanyLocation">Austria</td>
#             <td class="Rating">3</td>
#             <td class="BeanType">&nbsp;</td>
#             <td class="BroadBeanOrigin">Brazil</td>
#          </tr>
#       </table>
#       <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.2.8/d3.js"></script>
#    <script>(function(){var js = "window['__CF$cv$params']={r:'82cbe3a13e9dde43',t:'MTcwMTEwNDAyNi4wODgwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
soup=BeautifulSoup(webpage.content,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#          #cacaoTable {
#          border-collapse: collapse;
#          border: 2px black solid;
#          font: 12px sans-serif;
#          }
#          #cacaoTable td {
#          border: 1px black solid;
#          padding: 5px;
#          }
#          #infoContainer {
#          margin-bottom: 10px;
#          display: inline-block;
#          margin-right: 10px;
#          }
#          #chocolate {
#          width: 300px;
#          }
#          #picContainer {
#          display: inline;
#          }
#       </style>
# </head>
# <body>
# <!-- <script src="http://d3js.org/d3.v3.min.js"></script> -->
# <div id="banner">
# <h1>Cacao Ratings</h1>
# </div>
# <div id="infoContainer">
# <table class="infoTable">
# <tr>
# <td>Compiled ratings of over 1700 Chocolate bars</td>
# </tr>
# <tr>
# <td>Ratings are from 1-5</td>
# </tr>
# </table>
# </div>
# <div id="picContainer">
# <img id="chocolate" src="chocolate.jpg"/>
# </div>
# <table id="cacaoTable">
# <tr>
# <td class="Company">Company
#                (Maker-if known)
#             </td>
# <td class="Origin">Specific Bean Origin
#                or Bar Name
#             </td>
# <td class="REF">REF</td>
# <td class="ReviewDate">Review
#                Date
#             </td>
# <td class="CocoaPercent">Cocoa
#                Percent
#             </td>
# <td class="CompanyLocation">Company
#                Location
#             </td>
# <td class="Rating">Rating</td>
# <td class="BeanType">Bean
#                Type
#             </td>
# <td class="BroadBeanOrigin">Broad Bean
#                Origin
#             </td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Agua Grande</td>
# <td class="REF">1876</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">63%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Sao Tome</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Kpime</td>
# <td class="REF">1676</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Togo</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Atsane</td>
# <td class="REF">1676</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Togo</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Akata</td>
# <td class="REF">1680</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Togo</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Quilla</td>
# <td class="REF">1704</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Carenero</td>
# <td class="REF">1315</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Cuba</td>
# <td class="REF">1315</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Cuba</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Sur del Lago</td>
# <td class="REF">1315</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Puerto Cabello</td>
# <td class="REF">1319</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Pablino</td>
# <td class="REF">1319</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Panama</td>
# <td class="REF">1011</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Panama</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">1011</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Brazil</td>
# <td class="REF">1011</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Equateur</td>
# <td class="REF">1011</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Colombie</td>
# <td class="REF">1015</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Colombia</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Birmanie</td>
# <td class="REF">1015</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Burma</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Papua New Guinea</td>
# <td class="REF">1015</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Papua New Guinea</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Chuao</td>
# <td class="REF">1015</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">4</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Piura</td>
# <td class="REF">1019</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Chanchamayo Province</td>
# <td class="REF">1019</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Chanchamayo Province</td>
# <td class="REF">1019</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">63%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Bolivia</td>
# <td class="REF">797</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">A. Morin</td>
# <td class="Origin">Peru</td>
# <td class="REF">797</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">63%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Acalli</td>
# <td class="Origin">Chulucanas, El Platanal</td>
# <td class="REF">1462</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Acalli</td>
# <td class="Origin">Tumbes, Norandino</td>
# <td class="REF">1470</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Adi</td>
# <td class="Origin">Vanua Levu</td>
# <td class="REF">705</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">Fiji</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Fiji</td>
# </tr>
# <tr>
# <td class="Company">Adi</td>
# <td class="Origin">Vanua Levu, Toto-A</td>
# <td class="REF">705</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">80%</td>
# <td class="CompanyLocation">Fiji</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Fiji</td>
# </tr>
# <tr>
# <td class="Company">Adi</td>
# <td class="Origin">Vanua Levu</td>
# <td class="REF">705</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">88%</td>
# <td class="CompanyLocation">Fiji</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Fiji</td>
# </tr>
# <tr>
# <td class="Company">Adi</td>
# <td class="Origin">Vanua Levu, Ami-Ami-CA</td>
# <td class="REF">705</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">Fiji</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Fiji</td>
# </tr>
# <tr>
# <td class="Company">Aequare (Gianduja)</td>
# <td class="Origin">Los Rios, Quevedo, Arriba</td>
# <td class="REF">370</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">55%</td>
# <td class="CompanyLocation">Ecuador</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Forastero (Arriba)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Aequare (Gianduja)</td>
# <td class="Origin">Los Rios, Quevedo, Arriba</td>
# <td class="REF">370</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Ecuador</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero (Arriba)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Ah Cacao</td>
# <td class="Origin">Tabasco</td>
# <td class="REF">316</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Mexico</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Mexico</td>
# </tr>
# <tr>
# <td class="Company">Akesson's (Pralus)</td>
# <td class="Origin">Bali (west), Sukrama Family, Melaya area</td>
# <td class="REF">636</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Switzerland</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Indonesia</td>
# </tr>
# <tr>
# <td class="Company">Akesson's (Pralus)</td>
# <td class="Origin">Madagascar, Ambolikapiky P.</td>
# <td class="REF">502</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Switzerland</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Akesson's (Pralus)</td>
# <td class="Origin">Monte Alegre, D. Badero</td>
# <td class="REF">508</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Switzerland</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">Alain Ducasse</td>
# <td class="Origin">Trinite</td>
# <td class="REF">1215</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">65%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Alain Ducasse</td>
# <td class="Origin">Vietnam</td>
# <td class="REF">1215</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Vietnam</td>
# </tr>
# <tr>
# <td class="Company">Alain Ducasse</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">1215</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Alain Ducasse</td>
# <td class="Origin">Chuao</td>
# <td class="REF">1061</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Alain Ducasse</td>
# <td class="Origin">Piura, Perou</td>
# <td class="REF">1173</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Alexandre</td>
# <td class="Origin">Winak Coop, Napo</td>
# <td class="REF">1944</td>
# <td class="ReviewDate">2017</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Netherlands</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Forastero (Nacional)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Alexandre</td>
# <td class="Origin">La Dalia, Matagalpa</td>
# <td class="REF">1944</td>
# <td class="ReviewDate">2017</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Netherlands</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Nicaragua</td>
# </tr>
# <tr>
# <td class="Company">Alexandre</td>
# <td class="Origin">Tien Giang</td>
# <td class="REF">1944</td>
# <td class="ReviewDate">2017</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Netherlands</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Vietnam</td>
# </tr>
# <tr>
# <td class="Company">Alexandre</td>
# <td class="Origin">Makwale Village, Kyela</td>
# <td class="REF">1944</td>
# <td class="ReviewDate">2017</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Netherlands</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Tanzania</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Momotombo</td>
# <td class="REF">1728</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Nicaragua</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Acopagro</td>
# <td class="REF">1728</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">CIAAB Coop</td>
# <td class="REF">1732</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Villa Andina</td>
# <td class="REF">1732</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Gruppo Salinas</td>
# <td class="REF">1732</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Sur del Lago</td>
# <td class="REF">1125</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Conacado</td>
# <td class="REF">1125</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Bolivia</td>
# <td class="REF">1129</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">80%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Bolivia</td>
# <td class="REF">1133</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Altus aka Cao Artisan</td>
# <td class="Origin">Peru</td>
# <td class="REF">1133</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Morobe</td>
# <td class="REF">725</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Papua New Guinea</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Dos Rios</td>
# <td class="REF">470</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Guayas</td>
# <td class="REF">470</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Chuao</td>
# <td class="REF">544</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Montanya</td>
# <td class="REF">363</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Bali, Jembrana</td>
# <td class="REF">304</td>
# <td class="ReviewDate">2008</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Indonesia</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">129</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Cuyagua</td>
# <td class="REF">147</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amano</td>
# <td class="Origin">Ocumare</td>
# <td class="REF">175</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amatller (Simon Coll)</td>
# <td class="Origin">Ghana</td>
# <td class="REF">322</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Spain</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Ghana</td>
# </tr>
# <tr>
# <td class="Company">Amatller (Simon Coll)</td>
# <td class="Origin">Ecuador</td>
# <td class="REF">327</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Spain</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Amatller (Simon Coll)</td>
# <td class="Origin">Ecuador</td>
# <td class="REF">464</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">85%</td>
# <td class="CompanyLocation">Spain</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Amatller (Simon Coll)</td>
# <td class="Origin">Ghana</td>
# <td class="REF">464</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">85%</td>
# <td class="CompanyLocation">Spain</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Ghana</td>
# </tr>
# <tr>
# <td class="Company">Amazona</td>
# <td class="Origin">LamasdelChanka, San Martin, Oro Verde coop</td>
# <td class="REF">1145</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">Peru</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Amazona</td>
# <td class="Origin">Bellavista Gran Pajeten, San Martin</td>
# <td class="REF">1145</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">73%</td>
# <td class="CompanyLocation">Peru</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Ambrosia</td>
# <td class="Origin">Belize</td>
# <td class="REF">1494</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">64%</td>
# <td class="CompanyLocation">Canada</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Belize</td>
# </tr>
# <tr>
# <td class="Company">Ambrosia</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">1494</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">66%</td>
# <td class="CompanyLocation">Canada</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Ambrosia</td>
# <td class="Origin">Dominican Republic</td>
# <td class="REF">1498</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Canada</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Ambrosia</td>
# <td class="Origin">Papua New Guinea</td>
# <td class="REF">1498</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">63%</td>
# <td class="CompanyLocation">Canada</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Papua New Guinea</td>
# </tr>
# <tr>
# <td class="Company">Ambrosia</td>
# <td class="Origin">Venezuela</td>
# <td class="REF">1498</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Canada</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Ambrosia</td>
# <td class="Origin">Peru</td>
# <td class="REF">1498</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">68%</td>
# <td class="CompanyLocation">Canada</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Piura, Blanco de Criollo</td>
# <td class="REF">979</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Porcelana</td>
# <td class="REF">111</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">4</td>
# <td class="BeanType">Criollo (Porcelana)</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Nine</td>
# <td class="REF">111</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">4</td>
# <td class="BeanType">Blend</td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Chuao</td>
# <td class="REF">111</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Ecuador</td>
# <td class="REF">123</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Jamaica</td>
# <td class="REF">123</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Jamaica</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Grenada</td>
# <td class="REF">123</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Grenada</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Venezuela</td>
# <td class="REF">123</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario (85% Criollo)</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">123</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">4</td>
# <td class="BeanType">Trinitario (85% Criollo)</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Trinidad</td>
# <td class="REF">129</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Toscano Black</td>
# <td class="REF">170</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">63%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Blend</td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Toscano Black</td>
# <td class="REF">40</td>
# <td class="ReviewDate">2006</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">5</td>
# <td class="BeanType">Blend</td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Amedei</td>
# <td class="Origin">Toscano Black</td>
# <td class="REF">75</td>
# <td class="ReviewDate">2006</td>
# <td class="CocoaPercent">66%</td>
# <td class="CompanyLocation">Italy</td>
# <td class="Rating">4</td>
# <td class="BeanType">Blend</td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">AMMA</td>
# <td class="Origin">Catongo</td>
# <td class="REF">1065</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Brazil</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Forastero (Catongo)</td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">AMMA</td>
# <td class="Origin">Monte Alegre, 3 diff. plantations</td>
# <td class="REF">572</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">85%</td>
# <td class="CompanyLocation">Brazil</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Forastero (Parazinho)</td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">AMMA</td>
# <td class="Origin">Monte Alegre, 3 diff. plantations</td>
# <td class="REF">572</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">50%</td>
# <td class="CompanyLocation">Brazil</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Forastero (Parazinho)</td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">AMMA</td>
# <td class="Origin">Monte Alegre, 3 diff. plantations</td>
# <td class="REF">572</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Brazil</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Forastero (Parazinho)</td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">AMMA</td>
# <td class="Origin">Monte Alegre, 3 diff. plantations</td>
# <td class="REF">572</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">Brazil</td>
# <td class="Rating">4</td>
# <td class="BeanType">Forastero (Parazinho)</td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">Anahata</td>
# <td class="Origin">Elvesia</td>
# <td class="REF">1259</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Animas</td>
# <td class="Origin">Alto Beni</td>
# <td class="REF">1852</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Ara</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">1375</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Ara</td>
# <td class="Origin">Chiapas</td>
# <td class="REF">1379</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Mexico</td>
# </tr>
# <tr>
# <td class="Company">Ara</td>
# <td class="Origin">Equateur</td>
# <td class="REF">1379</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Ara</td>
# <td class="Origin">Trincheras</td>
# <td class="REF">1379</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">France</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">San Juan</td>
# <td class="REF">1724</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Kokoa Kamili</td>
# <td class="REF">1724</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Tanzania</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Tien Giang</td>
# <td class="REF">1900</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">73%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Vietnam</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Hacienda Victoria</td>
# <td class="REF">1904</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Costa Esmeraldas</td>
# <td class="REF">1904</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Lachua</td>
# <td class="REF">1904</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Guatemala</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Rugoso</td>
# <td class="REF">1904</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Nicaragua</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">La Masica, FHIA</td>
# <td class="REF">1908</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Honduras</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Coto Brus, Terciopelo</td>
# <td class="REF">1908</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Costa Rica</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Phantom</td>
# <td class="REF">1924</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">4</td>
# <td class="BeanType">Forastero (Nacional)</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Elvesia</td>
# <td class="REF">1928</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Matasawalevu</td>
# <td class="REF">1928</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Fiji</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Lam Dong</td>
# <td class="REF">1928</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">73%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Vietnam</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Fazenda Camboa</td>
# <td class="REF">1534</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Nacional</td>
# <td class="REF">1534</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">68%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Forastero (Nacional)</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Puerto Quito, heirloom</td>
# <td class="REF">1534</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Forastero (Nacional)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Oko Caribe</td>
# <td class="REF">1598</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Domincan Republic</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Maya Mountain</td>
# <td class="REF">1598</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Belize</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Chuno</td>
# <td class="REF">1598</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">4</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Nicaragua</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Fazenda Camboa</td>
# <td class="REF">1602</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Guatemala</td>
# <td class="REF">1602</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Guatemala</td>
# </tr>
# <tr>
# <td class="Company">Arete</td>
# <td class="Origin">Camino Verde</td>
# <td class="REF">1602</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Trinidad, Heritage, Limited ed.</td>
# <td class="REF">1193</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Colombia, Casa Luker</td>
# <td class="REF">947</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Colombia</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Haiti</td>
# <td class="REF">729</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Haiti</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Panama</td>
# <td class="REF">745</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Panama</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Venezuela</td>
# <td class="REF">486</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">100%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">1.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Jamaica</td>
# <td class="REF">531</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Jamaica</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Costa Rica</td>
# <td class="REF">600</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Costa Rica</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Ba Ria Vung Tau Province</td>
# <td class="REF">600</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Vietnam</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Bali</td>
# <td class="REF">600</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Indonesia</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Ocumare, Venezuela</td>
# <td class="REF">355</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Java</td>
# <td class="REF">355</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Indonesia</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Brazil Rio Doce</td>
# <td class="REF">363</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">1.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Madagascar</td>
# <td class="REF">363</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">80%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Peru</td>
# <td class="REF">363</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Dominican Republic</td>
# <td class="REF">363</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat</td>
# <td class="Origin">Congo</td>
# <td class="REF">300</td>
# <td class="ReviewDate">2008</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Congo</td>
# </tr>
# <tr>
# <td class="Company">Artisan du Chocolat (Casa Luker)</td>
# <td class="Origin">Orinoqua Region, Arauca</td>
# <td class="REF">1181</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.K.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Colombia</td>
# </tr>
# <tr>
# <td class="Company">Askinosie</td>
# <td class="Origin">Mababa</td>
# <td class="REF">1780</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">68%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Tanzania</td>
# </tr>
# <tr>
# <td class="Company">Askinosie</td>
# <td class="Origin">Tenende, Uwate</td>
# <td class="REF">647</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Tanzania</td>
# </tr>
# <tr>
# <td class="Company">Askinosie</td>
# <td class="Origin">Cortes</td>
# <td class="REF">661</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Honduras</td>
# </tr>
# <tr>
# <td class="Company">Askinosie</td>
# <td class="Origin">Davao</td>
# <td class="REF">331</td>
# <td class="ReviewDate">2009</td>
# <td class="CocoaPercent">77%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Philippines</td>
# </tr>
# <tr>
# <td class="Company">Askinosie</td>
# <td class="Origin">Xoconusco</td>
# <td class="REF">141</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Mexico</td>
# </tr>
# <tr>
# <td class="Company">Askinosie</td>
# <td class="Origin">San Jose del Tambo</td>
# <td class="REF">175</td>
# <td class="ReviewDate">2007</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero (Arriba)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Bahen &amp; Co.</td>
# <td class="Origin">Houseblend</td>
# <td class="REF">1474</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">80%</td>
# <td class="CompanyLocation">Australia</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Bahen &amp; Co.</td>
# <td class="Origin">Papua New Guinea</td>
# <td class="REF">1474</td>
# <td class="ReviewDate">2015</td>
# ...
# <td class="REF">1916</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ghana</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Maranon, Cajamarca</td>
# <td class="REF">1243</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero (Nacional)</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Camino Verde P., Balao, Guayas</td>
# <td class="REF">1042</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Gran Couva</td>
# <td class="REF">1042</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Ecuador</td>
# <td class="REF">825</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Costa Rica</td>
# <td class="REF">825</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Costa Rica</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Sambirano</td>
# <td class="REF">951</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">Ocumare</td>
# <td class="REF">741</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">4</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Venezuela</td>
# </tr>
# <tr>
# <td class="Company">Woodblock</td>
# <td class="Origin">La Red</td>
# <td class="REF">769</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Xocolat</td>
# <td class="Origin">Hispaniola</td>
# <td class="REF">1057</td>
# <td class="ReviewDate">2013</td>
# <td class="CocoaPercent">66%</td>
# <td class="CompanyLocation">Domincan Republic</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Xocolla</td>
# <td class="Origin">Sambirano, batch 170102</td>
# <td class="REF">1948</td>
# <td class="ReviewDate">2017</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Xocolla</td>
# <td class="Origin">Hispaniola, batch 170104</td>
# <td class="REF">1948</td>
# <td class="ReviewDate">2017</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">2.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Zak's</td>
# <td class="Origin">Papua New Guinea, Batch 2</td>
# <td class="REF">1574</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Papua New Guinea</td>
# </tr>
# <tr>
# <td class="Company">Zak's</td>
# <td class="Origin">Dominican Republic, Batch D2</td>
# <td class="REF">1578</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Domincan Republic</td>
# </tr>
# <tr>
# <td class="Company">Zak's</td>
# <td class="Origin">Madagascar, Batch 2</td>
# <td class="REF">1578</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Zak's</td>
# <td class="Origin">Peru, Batch 1</td>
# <td class="REF">1578</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Zak's</td>
# <td class="Origin">Belize, Batch 2</td>
# <td class="REF">1578</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Belize</td>
# </tr>
# <tr>
# <td class="Company">Zak's</td>
# <td class="Origin">House Blend, Batch 2</td>
# <td class="REF">1582</td>
# <td class="ReviewDate">2015</td>
# <td class="CocoaPercent">60%</td>
# <td class="CompanyLocation">U.S.A.</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Zart Pralinen</td>
# <td class="Origin">Millot P., Ambanja</td>
# <td class="REF">1820</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Madagascar</td>
# </tr>
# <tr>
# <td class="Company">Zart Pralinen</td>
# <td class="Origin">UNOCACE</td>
# <td class="REF">1824</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Nacional (Arriba)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Zart Pralinen</td>
# <td class="Origin">San Juan Estate</td>
# <td class="REF">1824</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">85%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">2.75</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Zart Pralinen</td>
# <td class="Origin">Kakao Kamili, Kilombero Valley</td>
# <td class="REF">1824</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">85%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Tanzania</td>
# </tr>
# <tr>
# <td class="Company">Zart Pralinen</td>
# <td class="Origin">Kakao Kamili, Kilombero Valley</td>
# <td class="REF">1824</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Tanzania</td>
# </tr>
# <tr>
# <td class="Company">Zart Pralinen</td>
# <td class="Origin">San Juan Estate, Gran Couva</td>
# <td class="REF">1880</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">78%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Trinidad</td>
# </tr>
# <tr>
# <td class="Company">Zokoko</td>
# <td class="Origin">Guadalcanal</td>
# <td class="REF">1716</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">78%</td>
# <td class="CompanyLocation">Australia</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Solomon Islands</td>
# </tr>
# <tr>
# <td class="Company">Zokoko</td>
# <td class="Origin">Goddess Blend</td>
# <td class="REF">1780</td>
# <td class="ReviewDate">2016</td>
# <td class="CocoaPercent">65%</td>
# <td class="CompanyLocation">Australia</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Zokoko</td>
# <td class="Origin">Alto Beni</td>
# <td class="REF">697</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">68%</td>
# <td class="CompanyLocation">Australia</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Zokoko</td>
# <td class="Origin">Tokiala</td>
# <td class="REF">701</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">66%</td>
# <td class="CompanyLocation">Australia</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Trinitario</td>
# <td class="BroadBeanOrigin">Papua New Guinea</td>
# </tr>
# <tr>
# <td class="Company">Zokoko</td>
# <td class="Origin">Tranquilidad, Baures</td>
# <td class="REF">701</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">Australia</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Raw</td>
# <td class="REF">1205</td>
# <td class="ReviewDate">2014</td>
# <td class="CocoaPercent">80%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">2.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Bocas del Toro, Cocabo Co-op</td>
# <td class="REF">801</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">72%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Panama</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Amazonas Frucht</td>
# <td class="REF">801</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">65%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Satipo Pangoa region, 16hr conche</td>
# <td class="REF">875</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo (Amarru)</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Satipo Pangoa region, 20hr conche</td>
# <td class="REF">875</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Criollo (Amarru)</td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Loma Los Pinos, Yacao region, D.R.</td>
# <td class="REF">875</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">62%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">El Oro</td>
# <td class="REF">879</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero (Nacional)</td>
# <td class="BroadBeanOrigin">Ecuador</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Huiwani Coop</td>
# <td class="REF">879</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">75%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3</td>
# <td class="BeanType">Criollo, Trinitario</td>
# <td class="BroadBeanOrigin">Papua New Guinea</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">El Ceibo Coop</td>
# <td class="REF">879</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">90%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Bolivia</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Santo Domingo</td>
# <td class="REF">879</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Dominican Republic</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Kongo, Highlands</td>
# <td class="REF">883</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">68%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.25</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Congo</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Indianer, Raw</td>
# <td class="REF">883</td>
# <td class="ReviewDate">2012</td>
# <td class="CocoaPercent">58%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin"> </td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Peru</td>
# <td class="REF">647</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">70%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.75</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Peru</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Congo</td>
# <td class="REF">749</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">65%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">Congo</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Kerala State</td>
# <td class="REF">749</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">65%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.5</td>
# <td class="BeanType">Forastero</td>
# <td class="BroadBeanOrigin">India</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Kerala State</td>
# <td class="REF">781</td>
# <td class="ReviewDate">2011</td>
# <td class="CocoaPercent">62%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3.25</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">India</td>
# </tr>
# <tr>
# <td class="Company">Zotter</td>
# <td class="Origin">Brazil, Mitzi Blue</td>
# <td class="REF">486</td>
# <td class="ReviewDate">2010</td>
# <td class="CocoaPercent">65%</td>
# <td class="CompanyLocation">Austria</td>
# <td class="Rating">3</td>
# <td class="BeanType"> </td>
# <td class="BroadBeanOrigin">Brazil</td>
# </tr>
# </table>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.2.8/d3.js"></script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'82cbd5dbee906ed3',t:'MTcwMTEwMzQ2MS45MDAwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
#Loop for inserting each table data to list
#Store the whole text in HTML that have the class "Rating" and "CocoaPercent"
rating_column = soup.find_all(attrs={"class": "Rating"})
cocoa_percent_tags = soup.find_all(attrs={"class": "CocoaPercent"})
#Make a empty lists for Rating and CocoaPercent
ratings = []
cocoa_percents = []
for x in rating_column[1:] :
    ratings.append(float(x.get_text()))

for td in cocoa_percent_tags[1:] :
    percent = float(td.get_text().strip('%'))
    cocoa_percents.append(percent)

#Combining both ratings and cocoa_percents list to a dictionary
data = {"Rating": ratings, "CocoaPercentage": cocoa_percents}

#Make a new Data Frame from data dictionary
df = pd.DataFrame.from_dict(data)
df
# Out:
#       Rating  CocoaPercentage
# 0       3.75             63.0
# 1       2.75             70.0
# 2       3.00             70.0
# 3       3.50             70.0
# 4       3.50             70.0
# ...      ...              ...
# 1790    3.75             70.0
# 1791    3.00             65.0
# 1792    3.50             65.0
# 1793    3.25             62.0
# 1794    3.00             65.0
#
# [1795 rows x 2 columns]

# %%
z=np.polyfit(df.CocoaPercentage,df.Rating,1)
line=np.poly1d(z)
plt.scatter(df.CocoaPercentage,df.Rating)
plt.title("CocoaPercentage & Rating")
plt.xlabel("Coca Percentage (%)")
plt.ylabel("Ratings")
plt.plot(df.CocoaPercentage,line_function(df.CocoaPercentage),"r--")
plt.show()

# %%
import requests
URL="https://www.geeksforgeeks.org/data-structures/"
r=requests.get(URL)
print(r.content)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<!--[if IE 7]>\r\n<html class="ie ie7" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if IE 8]>\r\n<html class="ie ie8" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\r\n<html lang="en-US" prefix="og: http://ogp.me/ns#" >\r\n\r\n<!--<![endif]-->\r\n<head>\r\n<meta charset="UTF-8" />\r\n<meta name="keywords" content="Data Structures, Algorithms, Python, Java, C, C++, JavaScript, Android Development, SQL, Data Science, Machine Learning, PHP, Web Development, System Design, Tutorial, Technical Blogs, Interview Experience, Interview Preparation, Programming, Competitive Programming, SDE Sheet, Job-a-thon, Coding Contests, GATE CSE, HTML, CSS, React, NodeJS, Placement, Aptitude, Quiz, Computer Science, Programming Examples, GeeksforGeeks Courses, Puzzles">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0"> \r\n\r\n<link rel="shortcut icon" href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" type="image/x-icon" />\r\n<link rel="preconnect" href="https://fonts.googleapis.com">\r\n<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\r\n\r\n<meta name="theme-color" content="#308D46" />\r\n\r\n<meta name="image" property="og:image" content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png">\r\n<meta property="og:image:type" content="image/png">\r\n<meta property="og:image:width" content="200">\r\n<meta property="og:image:height" content="200">\r\n<meta name="facebook-domain-verification" content="xo7t4ve2wn3ywfkjdvwbrk01pvdond" />\r\n\r\n<script defer src="https://apis.google.com/js/platform.js"></script>\r\n<script async src="//cdnjs.cloudflare.com/ajax/libs/require.js/2.1.14/require.min.js"></script>\r\n<!-- Removed the below script from here to prevent loading google translate js at initial load\r\n<script async src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit"></script> -->\r\n\r\n\r\n\r\n<title>Data Structures Tutorial - GeeksforGeeks</title>\r\n<link rel="profile" href="http://gmpg.org/xfn/11" />\r\n<link rel="pingback" href="" />\r\n<!--[if lt IE 9]>\r\n<script src="https://www.geeksforgeeks.org/wp-content/themes/iconic-one/js/html5.js" type="text/javascript"></script>\r\n<![endif]-->\r\n\r\n<script type="application/ld+json">\r\n    {\r\n        "@context" : "http://schema.org",\r\n        "@type" : "Organization",\r\n        "name" : "GeeksforGeeks",\r\n        "url" : "https://www.geeksforgeeks.org/",\r\n        "logo" : "https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200817185016/gfg_complete_logo_2x-min.png",\r\n        "description" : "A computer science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.",\r\n        "founder": [\r\n            {\r\n                "@type" : "Person",\r\n                "name" : "Sandeep Jain",\r\n                "url" : "https://in.linkedin.com/in/sandeep-jain-b3940815"\r\n            }\r\n        ],\r\n        "sameAs" : [ "https://www.facebook.com/geeksforgeeks.org/",\r\n            "https://twitter.com/geeksforgeeks",\r\n            "https://www.linkedin.com/company/1299009",\r\n            "https://www.youtube.com/geeksforgeeksvideos/"\r\n        ]\r\n    }\r\n</script>\r\n\r\n\r\n<!-- Question schema for single question posts only  -->\r\n\r\n<!-- adding article schema markup -->\r\n    <script type=\'application/ld+json\'>\r\n    {\r\n        "@context": "https://schema.org",\r\n        "@type": "Article",\r\n        "mainEntityOfPage": {\r\n          "@type": "WebPage",\r\n          "id": "https://www.geeksforgeeks.org/data-structures/"\r\n        },\r\n        "headline": "Data Structures Tutorial",\r\n        "datePublished": "2014-02-01 08:16:50",\r\n        "dateModified": " ...

# %%
import requests 
from bs4 import BeautifulSoup 
  
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 
soup=BeautifulSoup(r.content,'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="pass, it, on, passiton, values, kindness" name="keywords"/>
#   <meta content="The Foundation for a Better Life" name="twitter:site_name"/>
#   <meta content="@passiton_values" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Thank you for visiting." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" name="twitter:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" property="og:url"/>
#   <meta content="The Foundation for a Better Life" property="og:site_name"/>
#   <meta content="Welcome to PassItOn.com" property="og:title"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" property="og:image"/>
#   <meta content="Thank you for visiting." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/application-040b78d7e57ffee71891628c4812ae5eba0b121cd8fdf154d3a6a63f0d8514fd.css" rel="stylesheet"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="cjmcK_Z5M_Vo0R6_qcw_OS8bFp5g5gKvkZfKWXviDK-sx2uOUJA5qCUmhN-9Gmvm_d8zP1TFAgVtnPJEOWYXJg" name="csrf-token"/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1179606-29">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-1179606-29');
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window,document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#    fbq('init', '900394648046390');
#   fbq('track', 'PageView');
#   </script>
#   <noscript>
#   </noscript>
#  </head>
#  <body class="no-transition quotes_index">
#   <img height="1" src="https://www.facebook.com/tr?id=900394648046390&amp;ev=PageView
#   &amp;noscript=1" width="1"/>
#   <!-- End Facebook Pixel Code -->
#   <script>
#    window.fbAsyncInit = function() {
#       FB.init({
#         appId            : '483774921971842',
#         autoLogAppEvents : true,
#         xfbml            : true,
#         version          : 'v6.0'
#       });
#     };
#   </script>
#   <script async="" defer="" src="https://connect.facebook.net/en_US/sdk.js">
#   </script>
#   <meta content="483774921971842" property="fb:app_id"/>
#   <link href="https://www.passiton.com/inspirational-quotes.atom" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-WGXT9QJ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WGXT9QJ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <header>
#    <nav class="navbar navbar-default bootsnav background-transparent header-dark white-link navbar-fixed-top navbar-expand-lg nav-box-width">
#     <div class="container-fluid nav-header-container">
#      <div class="col-auto pl-0">
#       <a class="logo" href="/" title="Pass It On®">
#        <img alt="Pass It On" class="logo-dark" data-rjs="/assets/site/logo@2x-a5b7e9de4b8595ff3fc94c64e245592585dda8a14753ab6d4ce6a8e56155f543.png" src="/assets/site/logo-addf119432237cf6c743df6160193cf0c428b2bb9f6f258fef3f3fa1c710dd59.png"/>
#        <img alt="Pass It On" class="logo-light default" data-rjs="/assets/site/logo-white@2x-d49e37762eb5c6805d094397a8bca8b53d38c872c1fc54195093caff0208ad77.png" src="/assets/site/logo-white-cc0fccfb11de6149582eafd4805e8422c93875f0df879d387c1ac38a36dbead8.png"/>
#       </a>
#      </div>
#      <div class="col accordion-menu pr-0 pr-md-3">
#       <button class="navbar-toggler collapsed" data-target="#navbar-collapse-toggle-1" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <div class="navbar-collapse collapse justify-content-end" id="navbar-collapse-toggle-1">
#        <ul class="nav navbar-nav navbar-left no-margin alt-font text-normal" data-in="fadeIn" data-out="fadeOut" id="accordion">
#         <li>
#          <a href="/inspirational-quotes">
#           Quotes
#          </a>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/inspirational-stories-tv-spots">
#           Videos
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/inspirational-stories-tv-spots">
#             Official Pass It On® Videos
#            </a>
#           </li>
#           <li>
#            <a href="/artcenter-psas">
#             ArtCenter College of Design PSAs
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/inspirational-sayings-billboards">
#           Billboards
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/inspirational-sayings-billboards">
#             Official Billboards
#            </a>
#           </li>
#           <li>
#            <a href="/is-in-you">
#             Is In You® Billboards
#            </a>
#           </li>
#           <li>
#            <a href="/your-billboards">
#             Create Your Own Billboard
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a href="/share-your-values">
#           Submit
#          </a>
#         </li>
#         <li>
#          <a href="/positive-good-news-columns">
#           Newspapers
#          </a>
#         </li>
#         <li>
#          <a href="/radio">
#           Radio
#          </a>
#         </li>
#         <li>
#          <a href="/passiton-blog">
#           Blog
#          </a>
#         </li>
#         <li>
#          <a href="/poster-requests/new">
#           Schools
#          </a>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="#">
#           <i aria-hidden="true" class="fas fa-globe d-none d-lg-inline text-normal">
#           </i>
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="https://www.pasala.org/" target="_blank">
#             Spanish | Español
#            </a>
#           </li>
#           <li>
#            <a href="https://www.umavidamelhor.org/" target="_blank">
#             Portuguese | Português
#            </a>
#           </li>
#           <li>
#            <a href="https://www.values.cn.com/" target="_blank">
#             Chinese | 中文
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-auto pr-0">
#       <div class="header-searchbar">
#        <a aria-label="search form" class="header-search-form" href="#search-header">
#         <i class="fas fa-search search-button">
#         </i>
#        </a>
#        <form action="/search" class="mfp-hide search-form-result" id="search-header" method="post" name="search-header">
#         <div class="search-form position-relative">
#          <button aria-label="Search" class="fas fa-search close-search search-button" type="submit">
#          </button>
#          <input autocomplete="off" class="search-input" name="q" placeholder="Search passiton.com..." type="text"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <section class="parallax padding-six-all bg-black" data-stellar-background-ratio="0.2" style="background-image:url('/assets/backgrounds/flowers-7e362d59b798265063c210d16ea800b6fb4c3b13e462fbfe195df7c70c9811ce.jpg');">
#    <div class="container">
#     <div class="row justify-content-center">
#      <div class="col-12 col-lg-10 text-center">
#       <div class="shadow bg-extra-dark-gray padding-two-all border-radius-6 width-70 lg-width-80 sm-width-100 mx-auto lg-padding-30px-all sm-padding-15px-all sm-margin-40px-top">
#        <h6 class="font-weight-300 text-white-2 margin-20px-bottom sm-margin-15px-bottom">
#         Get our FREE daily quote emails!
#        </h6>
#        <p class="text-medium text-white-2 width-70 mx-auto margin-40px-bottom sm-width-100 sm-margin-15px-bottom">
#         Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe.
#        </p>
#        <form accept-charset="UTF-8" action="/users" class="simple_form search-box3 margin-10px-bottom" id="new_user" method="post" novalidate="novalidate">
#         <input autocomplete="off" name="authenticity_token" type="hidden" value="_cmXTmvqdC2piz8M60VYxJ2wZQKrYRYNGFqXf7RjrPWSO6gAAcI1BKW1tq48yMSi8i2AL5tXEIZZivGKTnaDNQ"/>
#         <script src="https://www.recaptcha.net/recaptcha/api.js?render=6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6">
#         </script>
#         <script>
#          // Define function so that we can call it again later if we need to reset it
#           // This executes reCAPTCHA and then calls our callback.
#           function executeRecaptchaForSignup() {
#             grecaptcha.ready(function() {
#               grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) {
#                 setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token)
#               });
#             });
#           };
#           // Invoke immediately
#           executeRecaptchaForSignup()
#
#           // Async variant so you can await this function from another async function (no need for
#           // an explicit callback function then!)
#           // Returns a Promise that resolves with the response token.
#           async function executeRecaptchaForSignupAsync() {
#             return new Promise((resolve, reject) => {
#              grecaptcha.ready(async function() {
#                 resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}))
#               });
#             })
#           };
#
#                     var setInputWithRecaptchaResponseTokenForSignup = function(id, token) {
#             var element = document.getElementById(id);
#             element.value = token;
#           }
#         </script>
#         <input class="g-recaptcha g-recaptcha-response" data-sitekey="6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6" id="g-recaptcha-response-data-signup" name="g-recaptcha-response-data[signup]" type="hidden"/>
#         <div class="input-group add-on width-75 mx-auto sm-width-100">
#          <input class="string email optional form-control text-white" id="user_email" label="false" name="user[email]" placeholder="you@youremail.com" type="text" value=""/>
#          <div class="input-group-append">
#           <button aria-label="Submit" class="btn btn-default" type="submit">
#            <i class="ti-arrow-right text-small m-0">
#            </i>
#           </button>
#          </div>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section class="half-section bg-extra-dark-gray half-section">
#    <div class="container">
#     <div class="row m-0">
#      <div class="col-12 d-flex flex-column justify-content-center text-center wow fadeIn" data-wow-delay="0.2s">
#       <h5 class="text-white alt-font font-weight-400 letter-spacing-1 margin-10px-bottom">
#        INSPIRATIONAL QUOTES
#       </h5>
#       <span class="text-white-2 opacity8 alt-font mb-0 padding-20px-bottom">
#        Find the perfect quote... and Pass It On®
#       </span>
#       <form action="/inspirational-quotes" class="search-box2 margin-30px-bottom" method="get">
#        <div class="input-group add-on width-75 mx-auto sm-width-100">
#         <input class="form-control text-white-2" name="q" placeholder="Search our inspiring quotes..." type="text" value=""/>
#         <div class="input-group-append">
#          <button aria-label="Search" class="btn btn-default" type="submit">
#           <i class="ti-search text-small m-0">
#           </i>
#          </button>
#         </div>
#        </div>
#       </form>
#      </div>
#     </div>
#     <div class="row m-0">
#      <div class="col-8 d-flex flex-column justify-content-top text-center">
#       <div class="row" id="all_quotes">
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7852-family-and-friends-are-hidden-treasures-seek">
#          <img alt="Family and friends are hidden treasures, seek them and enjoy their riches. #&lt;Author:0x00007fe2622d7548&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7852/medium/20231127_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7852-family-and-friends-are-hidden-treasures-seek">
#           FAMILY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8367-the-more-grateful-i-am-the-more-beauty-i-see">
#          <img alt="The more grateful I am, the more beauty I see. #&lt;Author:0x00007fe2622c4290&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8367/medium/20231124_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8367-the-more-grateful-i-am-the-more-beauty-i-see">
#           GRATITUDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/3105-gratitude-unlocks-the-fullness-of-life-it">
#          <img alt="Gratitude unlocks the fullness of life. It turns what we have into enough, and more. #&lt;Author:0x00007fe2622a7b18&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/3105/medium/20231123_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/3105-gratitude-unlocks-the-fullness-of-life-it">
#           GRATITUDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7426-as-we-express-our-gratitude-we-must-never">
#          <img alt="As we express our gratitude, we must never forget that the highest appreciation is not to utter words, but to live by them. #&lt;Author:0x00007fe2622fc668&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7426/medium/20231122_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7426-as-we-express-our-gratitude-we-must-never">
#           GRATITUDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8400-showing-gratitude-is-one-of-the-simplest-yet">
#          <img alt="Showing gratitude is one of the simplest yet most powerful things humans can do for each other. #&lt;Author:0x00007fe2622e5f58&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8400/medium/20231121_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8400-showing-gratitude-is-one-of-the-simplest-yet">
#           GRATITUDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8157-start-each-day-with-a-positive-thought-and-a">
#          <img alt="Start each day with a positive thought and a grateful heart. #&lt;Author:0x00007fe26232fba8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8157/medium/20231120_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8157-start-each-day-with-a-positive-thought-and-a">
#           GRATITUDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/5990-do-your-little-bit-of-good-where-you-are-its">
#          <img alt="Do your little bit of good where you are; its those little bits of good put together that overwhelm the world. #&lt;Author:0x00007fe26231d638&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/5990/medium/20231117_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/5990-do-your-little-bit-of-good-where-you-are-its">
#           MOTIVATION
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8399-as-we-work-to-create-light-for-others-we">
#          <img alt="As we work to create light for others, we naturally light our own way. #&lt;Author:0x00007fe262365e38&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8399/medium/20231116_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8399-as-we-work-to-create-light-for-others-we">
#           MOTIVATION
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6886-believe-you-can-and-youre-halfway-there">
#          <img alt="Believe you can and you're halfway there. #&lt;Author:0x00007fe26234ebe8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6886/medium/20231115_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6886-believe-you-can-and-youre-halfway-there">
#           MOTIVATION
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8398-you-must-expect-great-things-of-yourself-before">
#          <img alt="You must expect great things of yourself before you can do them. #&lt;Author:0x00007fe2614c3ab0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8398/medium/20231114_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8398-you-must-expect-great-things-of-yourself-before">
#           MOTIVATION
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7718-motivation-determines-what-you-do-attitude">
#          <img alt="Motivation determines what you do. Attitude determines how well you do it. #&lt;Author:0x00007fe262384a18&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7718/medium/20231113_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7718-motivation-determines-what-you-do-attitude">
#           MOTIVATION
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7474-the-purpose-of-life-is-a-life-of-purpose">
#          <img alt="The purpose of life is a life of purpose. #&lt;Author:0x00007fe26236dfe8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7474/medium/20231110_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7474-the-purpose-of-life-is-a-life-of-purpose">
#           PURPOSE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7304-the-two-most-important-days-in-your-life-are">
#          <img alt="The two most important days in your life are the day you are born and the day you find out why. #&lt;Author:0x00007fe2624064c8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7304/medium/20231109_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7304-the-two-most-important-days-in-your-life-are">
#           PURPOSE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6999-its-not-so-much-how-busy-you-are-but-why-you">
#          <img alt="It's not so much how busy you are, but why you are busy. #&lt;Author:0x00007fe2614cbe90&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6999/medium/20231108_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6999-its-not-so-much-how-busy-you-are-but-why-you">
#           PURPOSE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/5915-the-way-you-get-meaning-into-your-life-is-to">
#          <img alt="The way you get meaning into your life is to devote yourself to loving others, devote yourself to your community around you, and devote yourself to creating something that gives you purpose and meaning. #&lt;Author:0x00007fe262445100&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/5915/medium/20231107_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/5915-the-way-you-get-meaning-into-your-life-is-to">
#           PURPOSE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7472-the-meaning-of-life-is-to-find-your-gift-the">
#          <img alt="The meaning of life is to find your gift. The purpose of life is to give it away. #&lt;Author:0x00007fe26242dc80&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7472/medium/20231106_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7472-the-meaning-of-life-is-to-find-your-gift-the">
#           PURPOSE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8397-empathy-has-no-script-there-is-no-right-way-or">
#          <img alt="Empathy has no script. There is no right way or wrong way to do it. It’s simply listening, holding space, withholding judgment, emotionally connecting, and communicating that incredibly healing message of ‘You’re not alone.’ #&lt;Author:0x00007fe262486308&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8397/medium/20231103_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8397-empathy-has-no-script-there-is-no-right-way-or">
#           EMPATHY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8263-an-exchange-of-empathy-provides-an-entry-point">
#          <img alt="An exchange of empathy provides an entry point for a lot of people to see what healing feels like.  #&lt;Author:0x00007fe26246e370&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8263/medium/20231102_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8263-an-exchange-of-empathy-provides-an-entry-point">
#           EMPATHY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8133-empathy-is-seeing-with-the-eyes-of-another">
#          <img alt="Empathy is seeing with the eyes of another, listening with the ears of another, and feeling with the heart of another. – Alfred Adler #&lt;Author:0x00007fe262454498&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8133/medium/20231101_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8133-empathy-is-seeing-with-the-eyes-of-another">
#           EMPATHY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8261-empathy-is-about-finding-echoes-of-another">
#          <img alt="Empathy is about finding echoes of another person in yourself. #&lt;Author:0x00007fe2624a58e8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8261/medium/20231031_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8261-empathy-is-about-finding-echoes-of-another">
#           EMPATHY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8396-when-you-show-deep-empathy-toward-others-their">
#          <img alt="When you show deep empathy toward others, their defensive energy goes down, and positive energy replaces it. That’s when you can get more creative in solving problems. #&lt;Author:0x00007fe26248f660&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8396/medium/20231030_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8396-when-you-show-deep-empathy-toward-others-their">
#           EMPATHY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/4128-in-this-life-we-cannot-always-do-great-things">
#          <img alt="In this life we cannot always do great things. But we can do small things with great love. #&lt;Author:0x00007fe2625c4c38&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4128/medium/20231027_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/4128-in-this-life-we-cannot-always-do-great-things">
#           MAKING A DIFFERENCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7970-what-you-do-makes-a-difference-and-you-have-to">
#          <img alt="What you do makes a difference and you have to decide what kind of a difference you want to make. #&lt;Author:0x00007fe262526a10&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7970/medium/20231026_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7970-what-you-do-makes-a-difference-and-you-have-to">
#           MAKING A DIFFERENCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6231-it-takes-each-of-us-to-make-a-difference-for">
#          <img alt="It takes each of us to make a difference for all of us. #&lt;Author:0x00007fe2625fb940&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6231/medium/20231025_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6231-it-takes-each-of-us-to-make-a-difference-for">
#           MAKING A DIFFERENCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8149-each-one-of-us-can-make-a-difference-together">
#          <img alt="Each one of us can make a difference. Together we make a change. #&lt;Author:0x00007fe2625e8de0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8149/medium/20231024_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8149-each-one-of-us-can-make-a-difference-together">
#           MAKING A DIFFERENCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/3460-how-wonderful-that-no-one-need-wait-a-single">
#          <img alt="How wonderful that no one need wait a single moment to improve the world. #&lt;Author:0x00007fe262631f18&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/3460/medium/20231023_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/3460-how-wonderful-that-no-one-need-wait-a-single">
#           MAKING A DIFFERENCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8184-only-when-were-brave-enough-to-explore-the">
#          <img alt="Only when we're brave enough to explore the darkness will we discover the infinite power of our light. #&lt;Author:0x00007fe26261b498&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8184/medium/20231020_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8184-only-when-were-brave-enough-to-explore-the">
#           BRAVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8185-bravery-shows-up-in-everyday-life-when-people">
#          <img alt="Bravery shows up in everyday life when people have the courage to live their truth, their vision and their dreams. #&lt;Author:0x00007fe26266ff70&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8185/medium/20231019_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8185-bravery-shows-up-in-everyday-life-when-people">
#           BRAVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8183-bravery-is-the-audacity-to-be-unhindered-by">
#          <img alt="Bravery is the audacity to be unhindered by failures, and to walk with freedom, strength, and hope, in the face of things unknown. #&lt;Author:0x00007fe26265d7f8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8183/medium/20231018_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8183-bravery-is-the-audacity-to-be-unhindered-by">
#           BRAVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8395-bravery-is-not-the-absence-of-fear-but-action">
#          <img alt="Bravery is not the absence of fear, but action in the face of fear. #&lt;Author:0x00007fe26263adc0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8395/medium/20231017_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8395-bravery-is-not-the-absence-of-fear-but-action">
#           BRAVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8182-there-is-always-light-if-only-were-brave">
#          <img alt="There is always light, if only we're brave enough to see it. If only we're brave enough to be it. #&lt;Author:0x00007fe262697f70&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8182/medium/20231016_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8182-there-is-always-light-if-only-were-brave">
#           BRAVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8204-you-have-all-the-reason-in-the-world-to-achieve">
#          <img alt="You have all the reason in the world to achieve your grandest dreams. Imagination plus innovation equals realization. #&lt;Author:0x00007fe262684a38&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8204/medium/20231013_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8204-you-have-all-the-reason-in-the-world-to-achieve">
#           INNOVATION
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8345-vulnerability-is-the-birthplace-of-innovation">
#          <img alt="Vulnerability is the birthplace of innovation, creativity and change. #&lt;Author:0x00007fe2626cfc90&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8345/medium/20231012_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8345-vulnerability-is-the-birthplace-of-innovation">
#           INNOVATION
#          </a>
#         </h5>
#        </div>
#       </div>
#      </div>
#      <div class="col-4 d-flex flex-column text-center">
#       <div class="row" id="all_quotes">
#        <span class="text-white text-left alt-font font-weight-400 letter-spacing-1 margin-20px-bottom" style="font-size:  20px;">
#         We publish our quotes and other inspirational stories on Facebook. Please 'like' our page to get daily inspiration.
#        </span>
#        <div class="fb-page" data-adapt-container-width="true" data-height="3000" data-hide-cover="false" data-href="https://www.facebook.com/valuescom" data-show-facepile="true" data-small-header="true" data-tabs="timeline" data-width="">
#         <blockquote cite="https://www.facebook.com/valuescom" class="fb-xfbml-parse-ignore">
#          <a href="https://www.facebook.com/valuescom">
#           Foundation for A Better Life
#          </a>
#         </blockquote>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-12 text-center">
#       <nav aria-label="pager" class="pagination" role="navigation">
#        <span class="page current">
#         1
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=2" rel="next">
#          2
#         </a>
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=3">
#          3
#         </a>
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=4">
#          4
#         </a>
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=5">
#          5
#         </a>
#        </span>
#        <span class="page gap">
#         …
#        </span>
#        <span class="next">
#         <a href="/inspirational-quotes?page=2" rel="next">
#          Next ›
#         </a>
#        </span>
#        <span class="last">
#         <a href="/inspirational-quotes?page=78">
#          Last »
#         </a>
#        </span>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </section>
#   <footer class="footer-classic-dark bg-extra-dark-gray padding-five-bottom sm-padding-30px-bottom">
#    <div class="bg-dark-footer padding-50px-tb sm-padding-30px-tb">
#     <div class="container">
#      <div class="row align-items-center">
#       <div class="col-lg-4 col-md-4 sm-text-center lg-text-left alt-font sm-margin-15px-bottom">
#        <a href="/">
#         <img alt="PassItOn.com The Foundation for a Better Life" class="footer_logo" data-rjs="/assets/site/passiton_fbl_logo-130047b5350655ed0505fbb6bf8d137784664a78481a2ed020a9b5b73c7ec3d9.png" src="/assets/site/passiton_fbl_logo-130047b5350655ed0505fbb6bf8d137784664a78481a2ed020a9b5b73c7ec3d9.png" style="max-width: 200px;"/>
#        </a>
#       </div>
#       <div class="col-lg-4 col-md-4 text-center sm-margin-10px-bottom">
#       </div>
#       <div class="col-lg-4 col-md-4 text-center">
#        <span class="alt-font margin-20px-right text-light-gray">
#         Follow us on social
#        </span>
#        <div class="social-icon-style-8 d-inline-block vertical-align-middle">
#         <ul class="small-icon mb-0">
#          <li>
#           <a aria-label="facebook" class="facebook text-white-2" href="https://www.facebook.com/valuescom" target="_blank">
#            <i aria-hidden="true" class="fab fa-facebook-f">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="twitter" class="twitter text-white-2" href="https://twitter.com/passiton_values" target="_blank">
#            <i class="fab fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="instagram" class="instagram text-white-2" href="https://www.instagram.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-instagram no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="pinterest" class="pinterest text-white-2" href="https://www.pinterest.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-pinterest no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="youtube" class="youtube text-white-2" href="https://www.youtube.com/c/passiton_values" target="_blank">
#            <i aria-hidden="true" class="fab fa-youtube no-margin-right">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-widget-area padding-five-top padding-30px-bottom sm-padding-30px-top">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         Pass It On
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/share-your-values">
#           Help Us Inspire Others
#          </a>
#         </li>
#        </ul>
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         About Us
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/who-we-are">
#           About The Foundation for a Better Life
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/faqs">
#           FAQs
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/foundation-recognition">
#           Foundation Recognition
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/contact-us">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         Be Inspired
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/teaching-values">
#           Teaching Values
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-quotes">
#           Inspirational Quotations
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-stories-tv-spots">
#           Pass It On® Videos
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/artcenter-psas">
#           ArtCenter College of Design PSAs
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/positive-good-news-columns">
#           Free Newspaper Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/your-everyday-heroes">
#           Who's Your Hero Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-sayings-billboards">
#           Official Billboard Campaign
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/your-billboards">
#           Create Your Own Billboard
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/radio">
#           Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/passiton-blog">
#           Pass It On® Blog
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-audio-stories">
#           Podcasts
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-ecards">
#           Send an Ecard
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Schools
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/poster-requests/new">
#           Free Posters for Schools
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-downloads">
#           Downloads
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Media Companies
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/for-media-companies">
#           For Media Companies
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Broadcast Quality PSA Downloads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Pass It On Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Live Reads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Out of Home Materials
#          </a>
#         </li>
#        </ul>
#        <div class="row sm-margin-30px-top">
#         <div class="col-lg-4">
#          <a href="/">
#           <img alt="values.com logo" src="/assets/site/values_logo-d2f298a8d307ac7a45b2651f13796052ecfd37d37d73b102f7c910ee6e2eabc2.png" style="max-width: 70px;"/>
#          </a>
#         </div>
#         <div class="col-lg-7">
#          <p class="text-light-gray text-small padding-10px-top">
#           VALUES.COM
#           <small>
#            ®
#           </small>
#           is now PassItOn.com
#           <small>
#            ®
#           </small>
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="footer-bottom border-top border-color-medium-dark-gray padding-30px-top">
#      <div class="row">
#       <div class="col-lg-6 col-md-6 text-small text-light-gray text-md-left text-center">
#        ©2000-2023 The Foundation for a Better Life.
#       </div>
#       <div class="col-lg-6 col-md-6 text-small text-light-gray text-md-right text-center">
#        <a class="text-light-gray" href="/privacy-policy">
#         Privacy Policy
#        </a>
#        |
#        <a class="text-light-gray" href="/terms-of-use">
#         Terms of Use
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <a class="scroll-top-arrow" href="javascript:void(0);">
#    <i class="ti-arrow-up">
#    </i>
#   </a>
#   <script data-turbo-track="reload" src="/assets/application-8fb9b3ab633102f0313d3f5457328815a7f265d3783b8983a7e4c8bdbc3be1a8.js">
#   </script>
#   <script data-turbo-track="reload" src="/assets/popups-ea2746d4a69cf7c677be7cffcc597f962d136e705408c830a60e87a32efaf957.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-jcrop/0.9.15/js/jquery.Jcrop.min.js">
#   </script>
#   <div class="zoom-anim-dialog mfp-hide col-xl-6 col-lg-6 col-md-7 col-11 mx-auto bg-white text-center modal-popup-main padding-50px-all" id="follow_us_on_instagram">
#    <a class="instagram_invite" href="https://www.instagram.com/passiton_values/">
#     <img src="/assets/site/instagram-77257368680fe38005d9e9837c9b649a7625826e97d2993a0a1869b991fe330c.png" style="max-width: 150px;"/>
#    </a>
#    <br/>
#    <h6 class="font-weight-300 text-extra-dark-gray margin-20px-bottom sm-margin-15px-bottom">
#     DAILY INSPIRATION
#    </h6>
#    <p class="text-medium text-extra-dark-gray width-70 mx-auto margin-40px-bottom sm-width-100 sm-margin-15px-bottom">
#     <a class="instagram_invite text-decoration-underline" href="https://www.instagram.com/passiton_values/">
#      Follow PassItOn’s Instagram for a Daily Dose of Inspiration
#     </a>
#     .
#    </p>
#    <p>
#     <a class="instagram_invite btn btn-small btn-black btn-rounded" href="https://www.instagram.com/passiton_values/">
#      @passiton_values
#     </a>
#    </p>
#   </div>
#  </body>
# </html>

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
   
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 
   
soup = BeautifulSoup(r.content, 'html5lib') 
quotes=[]
table=soup.find('div',attrs={'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'})
table = soup.find('div', attrs = {'id':'all_quotes'})
for row in table.findAll('div', attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}): 
    quote = {} 
    quote['theme'] = row.h5.text 
    quote['url'] = row.a['href'] 
    quote['img'] = row.img['src'] 
    quote['lines'] = row.img['alt'].split(" #")[0] 
    quote['author'] = row.img['alt'].split(" #")[1] 
    quotes.append(quote) 
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f: 
    w = csv.DictWriter(f,['theme','url','img','lines','author']) 
    w.writeheader() 
    for quote in quotes: 
        w.writerow(quote)

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)
results = soup.find(id="ResultsContainer")
soup = BeautifulSoup(page.content, "html.parser")
job_elements = results.find_all("div", class_="card-content")
for job_element in job_elements:
    print(job_element, end="\n"*2)
# Out:
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Senior Python Developer</h2>
# <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Stewartbury, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Energy engineer</h2>
# <h3 class="subtitle is-6 company">Vasquez-Davidson</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Christopherville, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/energy-engineer-1.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Legal executive</h2>
# <h3 class="subtitle is-6 company">Jackson, Chambers and Levy</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Ericaburgh, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/legal-executive-2.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Fitness centre manager</h2>
# <h3 class="subtitle is-6 company">Savage-Bradley</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         East Seanview, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Product manager</h2>
# <h3 class="subtitle is-6 company">Ramirez Inc</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Jamieview, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/product-manager-4.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Medical technical officer</h2>
# <h3 class="subtitle is-6 company">Rogers-Yates</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Davidville, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Physiological scientist</h2>
# <h3 class="subtitle is-6 company">Kramer-Klein</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         South Christopher, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Textile designer</h2>
# <h3 class="subtitle is-6 company">Meyers-Johnson</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Jonathan, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/textile-designer-7.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Television floor manager</h2>
# <h3 class="subtitle is-6 company">Hughes-Williams</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Osbornetown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/television-floor-manager-8.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Waste management officer</h2>
# <h3 class="subtitle is-6 company">Jones, Williams and Villa</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Scotttown, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/waste-management-officer-9.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Software Engineer (Python)</h2>
# <h3 class="subtitle is-6 company">Garcia PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Ericberg, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/software-engineer-python-10.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Interpreter</h2>
# <h3 class="subtitle is-6 company">Gregory and Sons</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Ramireztown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/interpreter-11.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Architect</h2>
# <h3 class="subtitle is-6 company">Clark, Garcia and Sosa</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Figueroaview, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/architect-12.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Meteorologist</h2>
# <h3 class="subtitle is-6 company">Bush PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Kelseystad, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/meteorologist-13.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Audiological scientist</h2>
# <h3 class="subtitle is-6 company">Salazar-Meyers</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Williamsburgh, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/audiological-scientist-14.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">English as a second language teacher</h2>
# <h3 class="subtitle is-6 company">Parker, Murphy and Brooks</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Mitchellburgh, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/english-as-a-second-language-teacher-15.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Surgeon</h2>
# <h3 class="subtitle is-6 company">Cruz-Brown</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         West Jessicabury, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/surgeon-16.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Equities trader</h2>
# <h3 class="subtitle is-6 company">Macdonald-Ferguson</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Maloneshire, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/equities-trader-17.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Newspaper journalist</h2>
# <h3 class="subtitle is-6 company">Williams, Peterson and Rojas</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Johnsonton, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/newspaper-journalist-18.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Materials engineer</h2>
# <h3 class="subtitle is-6 company">Smith and Sons</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         South Davidtown, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/materials-engineer-19.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
# <h3 class="subtitle is-6 company">Moss, Duncan and Allen</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Sara, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-20.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Product/process development scientist</h2>
# <h3 class="subtitle is-6 company">Gomez-Carroll</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Marktown, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/product-process-development-scientist-21.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Scientist, research (maths)</h2>
# <h3 class="subtitle is-6 company">Manning, Welch and Herring</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Laurenland, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/scientist-research-maths-22.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Ecologist</h2>
# <h3 class="subtitle is-6 company">Lee, Gutierrez and Brown</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Lauraton, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/ecologist-23.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Materials engineer</h2>
# <h3 class="subtitle is-6 company">Davis, Serrano and Cook</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         South Tammyberg, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/materials-engineer-24.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Historic buildings inspector/conservation officer</h2>
# <h3 class="subtitle is-6 company">Smith LLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Brandonville, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/historic-buildings-inspector-conservation-officer-25.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Data scientist</h2>
# <h3 class="subtitle is-6 company">Thomas Group</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Robertfurt, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/data-scientist-26.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Psychiatrist</h2>
# <h3 class="subtitle is-6 company">Silva-King</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Burnettbury, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/psychiatrist-27.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Structural engineer</h2>
# <h3 class="subtitle is-6 company">Pierce-Long</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Herbertside, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/structural-engineer-28.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Immigration officer</h2>
# <h3 class="subtitle is-6 company">Walker-Simpson</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Christopherport, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/immigration-officer-29.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
# <h3 class="subtitle is-6 company">Cooper and Sons</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         West Victor, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-30.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Neurosurgeon</h2>
# <h3 class="subtitle is-6 company">Donovan, Gonzalez and Figueroa</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Aaron, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/neurosurgeon-31.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Broadcast engineer</h2>
# <h3 class="subtitle is-6 company">Morgan, Butler and Bennett</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Loribury, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/broadcast-engineer-32.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Make</h2>
# <h3 class="subtitle is-6 company">Snyder-Lee</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Angelastad, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/make-33.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Nurse, adult</h2>
# <h3 class="subtitle is-6 company">Harris PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Larrytown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/nurse-adult-34.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Air broker</h2>
# <h3 class="subtitle is-6 company">Washington PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         West Colin, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/air-broker-35.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Editor, film/video</h2>
# <h3 class="subtitle is-6 company">Brown, Price and Campbell</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         West Stephanie, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/editor-film-video-36.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Production assistant, radio</h2>
# <h3 class="subtitle is-6 company">Mcgee PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Laurentown, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/production-assistant-radio-37.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Engineer, communications</h2>
# <h3 class="subtitle is-6 company">Dixon Inc</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Wrightberg, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/engineer-communications-38.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Sales executive</h2>
# <h3 class="subtitle is-6 company">Thompson, Sheppard and Ward</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Alberttown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/sales-executive-39.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Software Developer (Python)</h2>
# <h3 class="subtitle is-6 company">Adams-Brewer</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Brockburgh, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/software-developer-python-40.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Futures trader</h2>
# <h3 class="subtitle is-6 company">Schneider-Brady</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Jason, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/futures-trader-41.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Tour manager</h2>
# <h3 class="subtitle is-6 company">Gonzales-Frank</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Arnoldhaven, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/tour-manager-42.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Cytogeneticist</h2>
# <h3 class="subtitle is-6 company">Smith-Wong</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Lake Destiny, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/cytogeneticist-43.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Designer, multimedia</h2>
# <h3 class="subtitle is-6 company">Pierce-Herrera</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         South Timothyburgh, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/designer-multimedia-44.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Trade union research officer</h2>
# <h3 class="subtitle is-6 company">Aguilar, Rivera and Quinn</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         New Jimmyton, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/trade-union-research-officer-45.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Chemist, analytical</h2>
# <h3 class="subtitle is-6 company">Lowe, Barnes and Thomas</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         New Lucasbury, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/chemist-analytical-46.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Programmer, multimedia</h2>
# <h3 class="subtitle is-6 company">Lewis, Gonzalez and Vasquez</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Cory, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/programmer-multimedia-47.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Engineer, broadcasting (operations)</h2>
# <h3 class="subtitle is-6 company">Taylor PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Gileston, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/engineer-broadcasting-operations-48.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Teacher, primary school</h2>
# <h3 class="subtitle is-6 company">Oliver, Jones and Ramirez</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Cindyshire, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/teacher-primary-school-49.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Python Developer</h2>
# <h3 class="subtitle is-6 company">Rivera and Sons</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         East Michaelfort, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/python-developer-50.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Manufacturing systems engineer</h2>
# <h3 class="subtitle is-6 company">Garcia PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Joybury, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/manufacturing-systems-engineer-51.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Producer, television/film/video</h2>
# <h3 class="subtitle is-6 company">Johnson, Wells and Kramer</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Emmatown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/producer-television-film-video-52.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Scientist, forensic</h2>
# <h3 class="subtitle is-6 company">Gonzalez LLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Colehaven, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/scientist-forensic-53.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Bonds trader</h2>
# <h3 class="subtitle is-6 company">Morgan, White and Macdonald</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Coryton, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/bonds-trader-54.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Editorial assistant</h2>
# <h3 class="subtitle is-6 company">Robinson-Fitzpatrick</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Amyborough, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/editorial-assistant-55.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Photographer</h2>
# <h3 class="subtitle is-6 company">Waters, Wilson and Hoover</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Reynoldsville, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/photographer-56.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# ...
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Warden/ranger</h2>
# <h3 class="subtitle is-6 company">Riley-Johnson</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         South Saratown, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/warden-ranger-81.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Sports therapist</h2>
# <h3 class="subtitle is-6 company">Spencer and Sons</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Hullview, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/sports-therapist-82.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Arts development officer</h2>
# <h3 class="subtitle is-6 company">Camacho-Sanchez</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Philipland, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/arts-development-officer-83.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Printmaker</h2>
# <h3 class="subtitle is-6 company">Oliver and Sons</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Patty, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/printmaker-84.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Health and safety adviser</h2>
# <h3 class="subtitle is-6 company">Eaton PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Stephen, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/health-and-safety-adviser-85.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Manufacturing systems engineer</h2>
# <h3 class="subtitle is-6 company">Stanley-Frederick</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Stevensland, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/manufacturing-systems-engineer-86.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Programmer, applications</h2>
# <h3 class="subtitle is-6 company">Bradley LLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Reyesstad, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/programmer-applications-87.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Medical physicist</h2>
# <h3 class="subtitle is-6 company">Parker, Goodwin and Zavala</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Bellberg, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/medical-physicist-88.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Media planner</h2>
# <h3 class="subtitle is-6 company">Kim-Miles</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Johnland, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/media-planner-89.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Software Developer (Python)</h2>
# <h3 class="subtitle is-6 company">Moreno-Rodriguez</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Martinezburgh, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/software-developer-python-90.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Surveyor, land/geomatics</h2>
# <h3 class="subtitle is-6 company">Brown-Ortiz</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Joshuatown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/surveyor-land-geomatics-91.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Legal executive</h2>
# <h3 class="subtitle is-6 company">Hartman PLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         West Ericstad, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/legal-executive-92.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Librarian, academic</h2>
# <h3 class="subtitle is-6 company">Brooks Inc</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Tuckertown, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/librarian-academic-93.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Barrister</h2>
# <h3 class="subtitle is-6 company">Washington-Castillo</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Perezton, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/barrister-94.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Museum/gallery exhibitions officer</h2>
# <h3 class="subtitle is-6 company">Nguyen, Yoder and Petty</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Lake Abigail, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/museum-gallery-exhibitions-officer-95.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Radiographer, diagnostic</h2>
# <h3 class="subtitle is-6 company">Holder LLC</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Jacobshire, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/radiographer-diagnostic-96.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Database administrator</h2>
# <h3 class="subtitle is-6 company">Yates-Ferguson</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Port Susan, AE
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/database-administrator-97.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Furniture designer</h2>
# <h3 class="subtitle is-6 company">Ortega-Lawrence</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         North Tiffany, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/furniture-designer-98.html" target="_blank">Apply</a>
# </footer>
# </div>
#
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Ship broker</h2>
# <h3 class="subtitle is-6 company">Fuentes, Walls and Castro</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Michelleville, AP
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/ship-broker-99.html" target="_blank">Apply</a>
# </footer>
# </div>

# %%
for job_element in job_elements:
    title_element = job_element.find("h2", class_="title")
    company_element = job_element.find("h3", class_="company")
    location_element = job_element.find("p", class_="location")
    print(title_element)
    print(company_element)
    print(location_element)
    print()
# Out:
# <h2 class="title is-5">Senior Python Developer</h2>
# <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
# <p class="location">
#         Stewartbury, AA
#       </p>
#
# <h2 class="title is-5">Energy engineer</h2>
# <h3 class="subtitle is-6 company">Vasquez-Davidson</h3>
# <p class="location">
#         Christopherville, AA
#       </p>
#
# <h2 class="title is-5">Legal executive</h2>
# <h3 class="subtitle is-6 company">Jackson, Chambers and Levy</h3>
# <p class="location">
#         Port Ericaburgh, AA
#       </p>
#
# <h2 class="title is-5">Fitness centre manager</h2>
# <h3 class="subtitle is-6 company">Savage-Bradley</h3>
# <p class="location">
#         East Seanview, AP
#       </p>
#
# <h2 class="title is-5">Product manager</h2>
# <h3 class="subtitle is-6 company">Ramirez Inc</h3>
# <p class="location">
#         North Jamieview, AP
#       </p>
#
# <h2 class="title is-5">Medical technical officer</h2>
# <h3 class="subtitle is-6 company">Rogers-Yates</h3>
# <p class="location">
#         Davidville, AP
#       </p>
#
# <h2 class="title is-5">Physiological scientist</h2>
# <h3 class="subtitle is-6 company">Kramer-Klein</h3>
# <p class="location">
#         South Christopher, AE
#       </p>
#
# <h2 class="title is-5">Textile designer</h2>
# <h3 class="subtitle is-6 company">Meyers-Johnson</h3>
# <p class="location">
#         Port Jonathan, AE
#       </p>
#
# <h2 class="title is-5">Television floor manager</h2>
# <h3 class="subtitle is-6 company">Hughes-Williams</h3>
# <p class="location">
#         Osbornetown, AE
#       </p>
#
# <h2 class="title is-5">Waste management officer</h2>
# <h3 class="subtitle is-6 company">Jones, Williams and Villa</h3>
# <p class="location">
#         Scotttown, AP
#       </p>
#
# <h2 class="title is-5">Software Engineer (Python)</h2>
# <h3 class="subtitle is-6 company">Garcia PLC</h3>
# <p class="location">
#         Ericberg, AE
#       </p>
#
# <h2 class="title is-5">Interpreter</h2>
# <h3 class="subtitle is-6 company">Gregory and Sons</h3>
# <p class="location">
#         Ramireztown, AE
#       </p>
#
# <h2 class="title is-5">Architect</h2>
# <h3 class="subtitle is-6 company">Clark, Garcia and Sosa</h3>
# <p class="location">
#         Figueroaview, AA
#       </p>
#
# <h2 class="title is-5">Meteorologist</h2>
# <h3 class="subtitle is-6 company">Bush PLC</h3>
# <p class="location">
#         Kelseystad, AA
#       </p>
#
# <h2 class="title is-5">Audiological scientist</h2>
# <h3 class="subtitle is-6 company">Salazar-Meyers</h3>
# <p class="location">
#         Williamsburgh, AE
#       </p>
#
# <h2 class="title is-5">English as a second language teacher</h2>
# <h3 class="subtitle is-6 company">Parker, Murphy and Brooks</h3>
# <p class="location">
#         Mitchellburgh, AE
#       </p>
#
# <h2 class="title is-5">Surgeon</h2>
# <h3 class="subtitle is-6 company">Cruz-Brown</h3>
# <p class="location">
#         West Jessicabury, AA
#       </p>
#
# <h2 class="title is-5">Equities trader</h2>
# <h3 class="subtitle is-6 company">Macdonald-Ferguson</h3>
# <p class="location">
#         Maloneshire, AE
#       </p>
#
# <h2 class="title is-5">Newspaper journalist</h2>
# <h3 class="subtitle is-6 company">Williams, Peterson and Rojas</h3>
# <p class="location">
#         Johnsonton, AA
#       </p>
#
# <h2 class="title is-5">Materials engineer</h2>
# <h3 class="subtitle is-6 company">Smith and Sons</h3>
# <p class="location">
#         South Davidtown, AP
#       </p>
#
# <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
# <h3 class="subtitle is-6 company">Moss, Duncan and Allen</h3>
# <p class="location">
#         Port Sara, AE
#       </p>
#
# <h2 class="title is-5">Product/process development scientist</h2>
# <h3 class="subtitle is-6 company">Gomez-Carroll</h3>
# <p class="location">
#         Marktown, AA
#       </p>
#
# <h2 class="title is-5">Scientist, research (maths)</h2>
# <h3 class="subtitle is-6 company">Manning, Welch and Herring</h3>
# <p class="location">
#         Laurenland, AE
#       </p>
#
# <h2 class="title is-5">Ecologist</h2>
# <h3 class="subtitle is-6 company">Lee, Gutierrez and Brown</h3>
# <p class="location">
#         Lauraton, AP
#       </p>
#
# <h2 class="title is-5">Materials engineer</h2>
# <h3 class="subtitle is-6 company">Davis, Serrano and Cook</h3>
# <p class="location">
#         South Tammyberg, AP
#       </p>
#
# <h2 class="title is-5">Historic buildings inspector/conservation officer</h2>
# <h3 class="subtitle is-6 company">Smith LLC</h3>
# <p class="location">
#         North Brandonville, AP
#       </p>
#
# <h2 class="title is-5">Data scientist</h2>
# <h3 class="subtitle is-6 company">Thomas Group</h3>
# <p class="location">
#         Port Robertfurt, AA
#       </p>
#
# <h2 class="title is-5">Psychiatrist</h2>
# <h3 class="subtitle is-6 company">Silva-King</h3>
# <p class="location">
#         Burnettbury, AE
#       </p>
#
# <h2 class="title is-5">Structural engineer</h2>
# <h3 class="subtitle is-6 company">Pierce-Long</h3>
# <p class="location">
#         Herbertside, AA
#       </p>
#
# <h2 class="title is-5">Immigration officer</h2>
# <h3 class="subtitle is-6 company">Walker-Simpson</h3>
# <p class="location">
#         Christopherport, AP
#       </p>
#
# <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
# <h3 class="subtitle is-6 company">Cooper and Sons</h3>
# <p class="location">
#         West Victor, AE
#       </p>
#
# <h2 class="title is-5">Neurosurgeon</h2>
# <h3 class="subtitle is-6 company">Donovan, Gonzalez and Figueroa</h3>
# <p class="location">
#         Port Aaron, AP
#       </p>
#
# <h2 class="title is-5">Broadcast engineer</h2>
# <h3 class="subtitle is-6 company">Morgan, Butler and Bennett</h3>
# <p class="location">
#         Loribury, AA
#       </p>
#
# <h2 class="title is-5">Make</h2>
# <h3 class="subtitle is-6 company">Snyder-Lee</h3>
# <p class="location">
#         Angelastad, AP
#       </p>
#
# <h2 class="title is-5">Nurse, adult</h2>
# <h3 class="subtitle is-6 company">Harris PLC</h3>
# <p class="location">
#         Larrytown, AE
#       </p>
#
# <h2 class="title is-5">Air broker</h2>
# <h3 class="subtitle is-6 company">Washington PLC</h3>
# <p class="location">
#         West Colin, AP
#       </p>
#
# <h2 class="title is-5">Editor, film/video</h2>
# <h3 class="subtitle is-6 company">Brown, Price and Campbell</h3>
# <p class="location">
#         West Stephanie, AP
#       </p>
#
# <h2 class="title is-5">Production assistant, radio</h2>
# <h3 class="subtitle is-6 company">Mcgee PLC</h3>
# <p class="location">
#         Laurentown, AP
#       </p>
#
# <h2 class="title is-5">Engineer, communications</h2>
# <h3 class="subtitle is-6 company">Dixon Inc</h3>
# <p class="location">
#         Wrightberg, AP
#       </p>
#
# <h2 class="title is-5">Sales executive</h2>
# <h3 class="subtitle is-6 company">Thompson, Sheppard and Ward</h3>
# <p class="location">
#         Alberttown, AE
#       </p>
#
# <h2 class="title is-5">Software Developer (Python)</h2>
# <h3 class="subtitle is-6 company">Adams-Brewer</h3>
# <p class="location">
#         Brockburgh, AE
#       </p>
#
# <h2 class="title is-5">Futures trader</h2>
# <h3 class="subtitle is-6 company">Schneider-Brady</h3>
# <p class="location">
#         North Jason, AE
#       </p>
#
# <h2 class="title is-5">Tour manager</h2>
# <h3 class="subtitle is-6 company">Gonzales-Frank</h3>
# <p class="location">
#         Arnoldhaven, AE
#       </p>
#
# <h2 class="title is-5">Cytogeneticist</h2>
# <h3 class="subtitle is-6 company">Smith-Wong</h3>
# <p class="location">
#         Lake Destiny, AP
#       </p>
#
# <h2 class="title is-5">Designer, multimedia</h2>
# <h3 class="subtitle is-6 company">Pierce-Herrera</h3>
# <p class="location">
#         South Timothyburgh, AP
#       </p>
#
# <h2 class="title is-5">Trade union research officer</h2>
# <h3 class="subtitle is-6 company">Aguilar, Rivera and Quinn</h3>
# <p class="location">
#         New Jimmyton, AE
#       </p>
#
# <h2 class="title is-5">Chemist, analytical</h2>
# <h3 class="subtitle is-6 company">Lowe, Barnes and Thomas</h3>
# <p class="location">
#         New Lucasbury, AP
#       </p>
#
# <h2 class="title is-5">Programmer, multimedia</h2>
# <h3 class="subtitle is-6 company">Lewis, Gonzalez and Vasquez</h3>
# <p class="location">
#         Port Cory, AE
#       </p>
#
# <h2 class="title is-5">Engineer, broadcasting (operations)</h2>
# <h3 class="subtitle is-6 company">Taylor PLC</h3>
# <p class="location">
#         Gileston, AA
#       </p>
#
# <h2 class="title is-5">Teacher, primary school</h2>
# <h3 class="subtitle is-6 company">Oliver, Jones and Ramirez</h3>
# <p class="location">
#         Cindyshire, AA
#       </p>
#
# <h2 class="title is-5">Python Developer</h2>
# <h3 class="subtitle is-6 company">Rivera and Sons</h3>
# <p class="location">
#         East Michaelfort, AA
#       </p>
#
# <h2 class="title is-5">Manufacturing systems engineer</h2>
# <h3 class="subtitle is-6 company">Garcia PLC</h3>
# <p class="location">
#         Joybury, AE
#       </p>
#
# <h2 class="title is-5">Producer, television/film/video</h2>
# <h3 class="subtitle is-6 company">Johnson, Wells and Kramer</h3>
# <p class="location">
#         Emmatown, AE
#       </p>
#
# <h2 class="title is-5">Scientist, forensic</h2>
# <h3 class="subtitle is-6 company">Gonzalez LLC</h3>
# <p class="location">
#         Colehaven, AP
#       </p>
#
# <h2 class="title is-5">Bonds trader</h2>
# <h3 class="subtitle is-6 company">Morgan, White and Macdonald</h3>
# <p class="location">
#         Port Coryton, AE
#       </p>
#
# <h2 class="title is-5">Editorial assistant</h2>
# <h3 class="subtitle is-6 company">Robinson-Fitzpatrick</h3>
# <p class="location">
#         Amyborough, AA
#       </p>
#
# <h2 class="title is-5">Photographer</h2>
# <h3 class="subtitle is-6 company">Waters, Wilson and Hoover</h3>
# <p class="location">
#         Reynoldsville, AA
#       </p>
#
# <h2 class="title is-5">Retail banker</h2>
# <h3 class="subtitle is-6 company">Hill LLC</h3>
# <p class="location">
#         Port Billy, AP
#       </p>
#
# <h2 class="title is-5">Jewellery designer</h2>
# <h3 class="subtitle is-6 company">Li-Gregory</h3>
# <p class="location">
#         Adamburgh, AA
#       </p>
#
# <h2 class="title is-5">Ophthalmologist</h2>
# <h3 class="subtitle is-6 company">Fisher, Ryan and Coleman</h3>
# <p class="location">
#         Wilsonmouth, AA
#       </p>
#
# <h2 class="title is-5">Back-End Web Developer (Python, Django)</h2>
# <h3 class="subtitle is-6 company">Stewart-Alexander</h3>
# <p class="location">
#         South Kimberly, AA
#       </p>
#
# <h2 class="title is-5">Licensed conveyancer</h2>
# <h3 class="subtitle is-6 company">Abbott and Sons</h3>
# <p class="location">
#         Benjaminland, AP
#       </p>
#
# <h2 class="title is-5">Futures trader</h2>
# <h3 class="subtitle is-6 company">Bryant, Santana and Davenport</h3>
# <p class="location">
#         Zacharyport, AA
#       </p>
#
# <h2 class="title is-5">Counselling psychologist</h2>
# <h3 class="subtitle is-6 company">Smith PLC</h3>
# <p class="location">
#         Port Devonville, AE
#       </p>
#
# <h2 class="title is-5">Insurance underwriter</h2>
# <h3 class="subtitle is-6 company">Patterson-Singh</h3>
# <p class="location">
#         East Thomas, AE
#       </p>
#
# <h2 class="title is-5">Engineer, automotive</h2>
# <h3 class="subtitle is-6 company">Martinez-Berry</h3>
# <p class="location">
#         New Jeffrey, AP
#       </p>
#
# <h2 class="title is-5">Producer, radio</h2>
# <h3 class="subtitle is-6 company">May, Taylor and Fisher</h3>
# <p class="location">
#         Davidside, AA
#       </p>
#
# <h2 class="title is-5">Dispensing optician</h2>
# <h3 class="subtitle is-6 company">Bailey, Owen and Thompson</h3>
# <p class="location">
#         Jamesville, AA
#       </p>
#
# <h2 class="title is-5">Designer, fashion/clothing</h2>
# <h3 class="subtitle is-6 company">Vasquez Ltd</h3>
# <p class="location">
#         New Kelly, AP
#       </p>
#
# <h2 class="title is-5">Chartered loss adjuster</h2>
# <h3 class="subtitle is-6 company">Leblanc LLC</h3>
# <p class="location">
#         Lake Antonio, AA
#       </p>
#
# <h2 class="title is-5">Back-End Web Developer (Python, Django)</h2>
# <h3 class="subtitle is-6 company">Jackson, Ali and Mckee</h3>
# <p class="location">
#         New Elizabethside, AA
#       </p>
#
# <h2 class="title is-5">Forest/woodland manager</h2>
# <h3 class="subtitle is-6 company">Blankenship, Knight and Powell</h3>
# <p class="location">
#         Millsbury, AE
#       </p>
#
# <h2 class="title is-5">Clinical cytogeneticist</h2>
# <h3 class="subtitle is-6 company">Patton, Haynes and Jones</h3>
# <p class="location">
#         Lloydton, AP
#       </p>
#
# <h2 class="title is-5">Print production planner</h2>
# <h3 class="subtitle is-6 company">Wood Inc</h3>
# <p class="location">
#         Port Jeremy, AA
#       </p>
#
# <h2 class="title is-5">Systems developer</h2>
# <h3 class="subtitle is-6 company">Collins Group</h3>
# <p class="location">
#         New Elizabethtown, AA
#       </p>
#
# <h2 class="title is-5">Graphic designer</h2>
# <h3 class="subtitle is-6 company">Flores-Nelson</h3>
# <p class="location">
#         Charlesstad, AE
#       </p>
#
# <h2 class="title is-5">Writer</h2>
# <h3 class="subtitle is-6 company">Mitchell, Jones and Olson</h3>
# <p class="location">
#         Josephbury, AE
#       </p>
#
# <h2 class="title is-5">Field seismologist</h2>
# <h3 class="subtitle is-6 company">Howard Group</h3>
# <p class="location">
#         Seanfurt, AA
#       </p>
#
# <h2 class="title is-5">Chief Strategy Officer</h2>
# <h3 class="subtitle is-6 company">Kramer-Edwards</h3>
# <p class="location">
#         Williambury, AA
#       </p>
#
# <h2 class="title is-5">Air cabin crew</h2>
# <h3 class="subtitle is-6 company">Berry-Houston</h3>
# <p class="location">
#         South Jorgeside, AP
#       </p>
#
# <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
# <h3 class="subtitle is-6 company">Mathews Inc</h3>
# <p class="location">
#         Robertborough, AP
#       </p>
#
# <h2 class="title is-5">Warden/ranger</h2>
# <h3 class="subtitle is-6 company">Riley-Johnson</h3>
# <p class="location">
#         South Saratown, AP
#       </p>
#
# <h2 class="title is-5">Sports therapist</h2>
# <h3 class="subtitle is-6 company">Spencer and Sons</h3>
# <p class="location">
#         Hullview, AA
#       </p>
#
# <h2 class="title is-5">Arts development officer</h2>
# <h3 class="subtitle is-6 company">Camacho-Sanchez</h3>
# <p class="location">
#         Philipland, AP
#       </p>
#
# <h2 class="title is-5">Printmaker</h2>
# <h3 class="subtitle is-6 company">Oliver and Sons</h3>
# <p class="location">
#         North Patty, AE
#       </p>
#
# <h2 class="title is-5">Health and safety adviser</h2>
# <h3 class="subtitle is-6 company">Eaton PLC</h3>
# <p class="location">
#         North Stephen, AE
#       </p>
#
# <h2 class="title is-5">Manufacturing systems engineer</h2>
# <h3 class="subtitle is-6 company">Stanley-Frederick</h3>
# <p class="location">
#         Stevensland, AP
#       </p>
#
# <h2 class="title is-5">Programmer, applications</h2>
# <h3 class="subtitle is-6 company">Bradley LLC</h3>
# <p class="location">
#         Reyesstad, AE
#       </p>
#
# <h2 class="title is-5">Medical physicist</h2>
# <h3 class="subtitle is-6 company">Parker, Goodwin and Zavala</h3>
# <p class="location">
#         Bellberg, AP
#       </p>
#
# <h2 class="title is-5">Media planner</h2>
# <h3 class="subtitle is-6 company">Kim-Miles</h3>
# <p class="location">
#         North Johnland, AE
#       </p>
#
# <h2 class="title is-5">Software Developer (Python)</h2>
# <h3 class="subtitle is-6 company">Moreno-Rodriguez</h3>
# <p class="location">
#         Martinezburgh, AE
#       </p>
#
# <h2 class="title is-5">Surveyor, land/geomatics</h2>
# <h3 class="subtitle is-6 company">Brown-Ortiz</h3>
# <p class="location">
#         Joshuatown, AE
#       </p>
#
# <h2 class="title is-5">Legal executive</h2>
# <h3 class="subtitle is-6 company">Hartman PLC</h3>
# <p class="location">
#         West Ericstad, AA
#       </p>
#
# <h2 class="title is-5">Librarian, academic</h2>
# <h3 class="subtitle is-6 company">Brooks Inc</h3>
# <p class="location">
#         Tuckertown, AE
#       </p>
#
# <h2 class="title is-5">Barrister</h2>
# <h3 class="subtitle is-6 company">Washington-Castillo</h3>
# <p class="location">
#         Perezton, AE
#       </p>
#
# <h2 class="title is-5">Museum/gallery exhibitions officer</h2>
# <h3 class="subtitle is-6 company">Nguyen, Yoder and Petty</h3>
# <p class="location">
#         Lake Abigail, AE
#       </p>
#
# <h2 class="title is-5">Radiographer, diagnostic</h2>
# <h3 class="subtitle is-6 company">Holder LLC</h3>
# <p class="location">
#         Jacobshire, AP
#       </p>
#
# <h2 class="title is-5">Database administrator</h2>
# <h3 class="subtitle is-6 company">Yates-Ferguson</h3>
# <p class="location">
#         Port Susan, AE
#       </p>
#
# <h2 class="title is-5">Furniture designer</h2>
# <h3 class="subtitle is-6 company">Ortega-Lawrence</h3>
# <p class="location">
#         North Tiffany, AA
#       </p>
#
# <h2 class="title is-5">Ship broker</h2>
# <h3 class="subtitle is-6 company">Fuentes, Walls and Castro</h3>
# <p class="location">
#         Michelleville, AP
#       </p>

# %%
for job_element in job_elements:
    title_element = job_element.find("h2", class_="title")
    company_element = job_element.find("h3", class_="company")
    location_element = job_element.find("p", class_="location")
    print(title_element.text)
    print(company_element.text)
    print(location_element.text)
    print()
# Out:
# Senior Python Developer
# Payne, Roberts and Davis
#
#         Stewartbury, AA
#
#
# Energy engineer
# Vasquez-Davidson
#
#         Christopherville, AA
#
#
# Legal executive
# Jackson, Chambers and Levy
#
#         Port Ericaburgh, AA
#
#
# Fitness centre manager
# Savage-Bradley
#
#         East Seanview, AP
#
#
# Product manager
# Ramirez Inc
#
#         North Jamieview, AP
#
#
# Medical technical officer
# Rogers-Yates
#
#         Davidville, AP
#
#
# Physiological scientist
# Kramer-Klein
#
#         South Christopher, AE
#
#
# Textile designer
# Meyers-Johnson
#
#         Port Jonathan, AE
#
#
# Television floor manager
# Hughes-Williams
#
#         Osbornetown, AE
#
#
# Waste management officer
# Jones, Williams and Villa
#
#         Scotttown, AP
#
#
# Software Engineer (Python)
# Garcia PLC
#
#         Ericberg, AE
#
#
# Interpreter
# Gregory and Sons
#
#         Ramireztown, AE
#
#
# Architect
# Clark, Garcia and Sosa
#
#         Figueroaview, AA
#
#
# Meteorologist
# Bush PLC
#
#         Kelseystad, AA
#
#
# Audiological scientist
# Salazar-Meyers
#
#         Williamsburgh, AE
#
#
# English as a second language teacher
# Parker, Murphy and Brooks
#
#         Mitchellburgh, AE
#
#
# Surgeon
# Cruz-Brown
#
#         West Jessicabury, AA
#
#
# Equities trader
# Macdonald-Ferguson
#
#         Maloneshire, AE
#
#
# Newspaper journalist
# Williams, Peterson and Rojas
#
#         Johnsonton, AA
#
#
# Materials engineer
# Smith and Sons
#
#         South Davidtown, AP
#
#
# Python Programmer (Entry-Level)
# Moss, Duncan and Allen
#
#         Port Sara, AE
#
#
# Product/process development scientist
# Gomez-Carroll
#
#         Marktown, AA
#
#
# Scientist, research (maths)
# Manning, Welch and Herring
#
#         Laurenland, AE
#
#
# Ecologist
# Lee, Gutierrez and Brown
#
#         Lauraton, AP
#
#
# Materials engineer
# Davis, Serrano and Cook
#
#         South Tammyberg, AP
#
#
# Historic buildings inspector/conservation officer
# Smith LLC
#
#         North Brandonville, AP
#
#
# Data scientist
# Thomas Group
#
#         Port Robertfurt, AA
#
#
# Psychiatrist
# Silva-King
#
#         Burnettbury, AE
#
#
# Structural engineer
# Pierce-Long
#
#         Herbertside, AA
#
#
# Immigration officer
# Walker-Simpson
#
#         Christopherport, AP
#
#
# Python Programmer (Entry-Level)
# Cooper and Sons
#
#         West Victor, AE
#
#
# Neurosurgeon
# Donovan, Gonzalez and Figueroa
#
#         Port Aaron, AP
#
#
# Broadcast engineer
# Morgan, Butler and Bennett
#
#         Loribury, AA
#
#
# Make
# Snyder-Lee
#
#         Angelastad, AP
#
#
# Nurse, adult
# Harris PLC
#
#         Larrytown, AE
#
#
# Air broker
# Washington PLC
#
#         West Colin, AP
#
#
# Editor, film/video
# Brown, Price and Campbell
#
#         West Stephanie, AP
#
#
# Production assistant, radio
# Mcgee PLC
#
#         Laurentown, AP
#
#
# Engineer, communications
# Dixon Inc
#
#         Wrightberg, AP
#
#
# Sales executive
# Thompson, Sheppard and Ward
#
#         Alberttown, AE
#
#
# Software Developer (Python)
# Adams-Brewer
#
#         Brockburgh, AE
#
#
# Futures trader
# Schneider-Brady
#
#         North Jason, AE
#
#
# Tour manager
# Gonzales-Frank
#
#         Arnoldhaven, AE
#
#
# Cytogeneticist
# Smith-Wong
#
#         Lake Destiny, AP
#
#
# Designer, multimedia
# Pierce-Herrera
#
#         South Timothyburgh, AP
#
#
# Trade union research officer
# Aguilar, Rivera and Quinn
#
#         New Jimmyton, AE
#
#
# Chemist, analytical
# Lowe, Barnes and Thomas
#
#         New Lucasbury, AP
#
#
# Programmer, multimedia
# Lewis, Gonzalez and Vasquez
#
#         Port Cory, AE
#
#
# Engineer, broadcasting (operations)
# Taylor PLC
#
#         Gileston, AA
#
#
# Teacher, primary school
# Oliver, Jones and Ramirez
#
#         Cindyshire, AA
#
#
# Python Developer
# Rivera and Sons
#
#         East Michaelfort, AA
#
#
# Manufacturing systems engineer
# Garcia PLC
#
#         Joybury, AE
#
#
# Producer, television/film/video
# Johnson, Wells and Kramer
#
#         Emmatown, AE
#
#
# Scientist, forensic
# Gonzalez LLC
#
#         Colehaven, AP
#
#
# Bonds trader
# Morgan, White and Macdonald
#
#         Port Coryton, AE
#
#
# Editorial assistant
# Robinson-Fitzpatrick
#
#         Amyborough, AA
#
#
# Photographer
# Waters, Wilson and Hoover
#
#         Reynoldsville, AA
#
#
# Retail banker
# Hill LLC
#
#         Port Billy, AP
#
#
# Jewellery designer
# Li-Gregory
#
#         Adamburgh, AA
#
#
# Ophthalmologist
# Fisher, Ryan and Coleman
#
#         Wilsonmouth, AA
#
#
# Back-End Web Developer (Python, Django)
# Stewart-Alexander
#
#         South Kimberly, AA
#
#
# Licensed conveyancer
# Abbott and Sons
#
#         Benjaminland, AP
#
#
# Futures trader
# Bryant, Santana and Davenport
#
#         Zacharyport, AA
#
#
# Counselling psychologist
# Smith PLC
#
#         Port Devonville, AE
#
#
# Insurance underwriter
# Patterson-Singh
#
#         East Thomas, AE
#
#
# Engineer, automotive
# Martinez-Berry
#
#         New Jeffrey, AP
#
#
# Producer, radio
# May, Taylor and Fisher
#
#         Davidside, AA
#
#
# Dispensing optician
# Bailey, Owen and Thompson
#
#         Jamesville, AA
#
#
# Designer, fashion/clothing
# Vasquez Ltd
#
#         New Kelly, AP
#
#
# Chartered loss adjuster
# Leblanc LLC
#
#         Lake Antonio, AA
#
#
# Back-End Web Developer (Python, Django)
# Jackson, Ali and Mckee
#
#         New Elizabethside, AA
#
#
# Forest/woodland manager
# Blankenship, Knight and Powell
#
#         Millsbury, AE
#
#
# Clinical cytogeneticist
# Patton, Haynes and Jones
#
#         Lloydton, AP
#
#
# Print production planner
# Wood Inc
#
#         Port Jeremy, AA
#
#
# Systems developer
# Collins Group
#
#         New Elizabethtown, AA
#
#
# Graphic designer
# Flores-Nelson
#
#         Charlesstad, AE
#
#
# Writer
# Mitchell, Jones and Olson
#
#         Josephbury, AE
#
#
# Field seismologist
# Howard Group
#
#         Seanfurt, AA
#
#
# Chief Strategy Officer
# Kramer-Edwards
#
#         Williambury, AA
#
#
# Air cabin crew
# Berry-Houston
#
#         South Jorgeside, AP
#
#
# Python Programmer (Entry-Level)
# Mathews Inc
#
#         Robertborough, AP
#
#
# Warden/ranger
# Riley-Johnson
#
#         South Saratown, AP
#
#
# Sports therapist
# Spencer and Sons
#
#         Hullview, AA
#
#
# Arts development officer
# Camacho-Sanchez
#
#         Philipland, AP
#
#
# Printmaker
# Oliver and Sons
#
#         North Patty, AE
#
#
# Health and safety adviser
# Eaton PLC
#
#         North Stephen, AE
#
#
# Manufacturing systems engineer
# Stanley-Frederick
#
#         Stevensland, AP
#
#
# Programmer, applications
# Bradley LLC
#
#         Reyesstad, AE
#
#
# Medical physicist
# Parker, Goodwin and Zavala
#
#         Bellberg, AP
#
#
# Media planner
# Kim-Miles
#
#         North Johnland, AE
#
#
# Software Developer (Python)
# Moreno-Rodriguez
#
#         Martinezburgh, AE
#
#
# Surveyor, land/geomatics
# Brown-Ortiz
#
#         Joshuatown, AE
#
#
# Legal executive
# Hartman PLC
#
#         West Ericstad, AA
#
#
# Librarian, academic
# Brooks Inc
#
#         Tuckertown, AE
#
#
# Barrister
# Washington-Castillo
#
#         Perezton, AE
#
#
# Museum/gallery exhibitions officer
# Nguyen, Yoder and Petty
#
#         Lake Abigail, AE
#
#
# Radiographer, diagnostic
# Holder LLC
#
#         Jacobshire, AP
#
#
# Database administrator
# Yates-Ferguson
#
#         Port Susan, AE
#
#
# Furniture designer
# Ortega-Lawrence
#
#         North Tiffany, AA
#
#
# Ship broker
# Fuentes, Walls and Castro
#
#         Michelleville, AP

# %%
python_jobs = results.find_all("h2", string="Python")
print(python_jobs)
# Out:
# []

# %%
python_jobs = results.find_all("h2", string=lambda text: "python" in text.lower())
print(len(python_jobs))
# Out:
# 10

# %%
python_jobs = results.find_all("h2", string=lambda text: "python" in text.lower())

python_job_elements = [h2_element.parent.parent.parent for h2_element in python_jobs]
python_job_elements
for job_element in python_job_elements:
    # -- snip --
    links = job_element.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply
# Learn
# Apply

# %%
for job_element in python_job_elements:
    # -- snip --
    links = job_element.find_all("a")
    for link in links:
        link_url = link["href"]
        print(f"Apply here: {link_url}\n")
# Out:
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/software-engineer-python-10.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-20.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-30.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/software-developer-python-40.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/python-developer-50.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/back-end-web-developer-python-django-60.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/back-end-web-developer-python-django-70.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-80.html
#
# Apply here: https://www.realpython.com
#
# Apply here: https://realpython.github.io/fake-jobs/jobs/software-developer-python-90.html
