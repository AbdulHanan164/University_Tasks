# %%
#Question 1
class Recipe:
    def __init__(self,ingredients,instructions,ingredients_quality):
        self.ingredients=ingredients
        self.instruction=instructions
        self.ingredients_quality=ingredients_quality
        ingredients_list=[]
    def Adding(self,ingredients):
        self.ingredients.append(ingredients)
    def Removing(self.ingredients):
        self.ingredients.remove(ingredients)
    def checking(self,has_ingredients,has_all_ingredients):
        self.has_all_ingredients=self.ingredients
        if has_ingredients in self.ingredients:
            print("Ingredient Found!")
        else:
            print("ingredient not Found!")
        for i in self.has_all_ingredients:
            if self.has_all_ingredients[i]==self.ingredients[i]:
                print("All ingredients found!")
            elif self.has_all_ingredients[i]!=self.ingredients[i]:
                print("All ingredients not found!")
    def get_description(self):
        self.string=input("Enter a Description for a string")
        return self.string
    def __eq__(self,other):
        return Recipe(self.ingredient==other.ingredient)
    def __add__(self,other,recipe):
        other.ingredient.append(recipe)
        return Recipe(self.ingredient+other.ingredient)
    def __sub__(self,recipe,other):
        other.ingredient.append(recipe)
        return Recipe(self.ingredient-other.ingredient)
    def __noteq__(self,other):
        return Recipe(self.ingredient!=other.ingredient)
    def find_recipe (self,recipe):
        self.recipe=recipe
        if self.recipe in self.ingredients:
            print("Found")
        else:
            print("not Found")
ingredients=[]
while True:
    print("\nPress 1 to Add new Recipe :")   
    print("Press 2 to Update Product :")
    print("Press 3 to check recipe")
    choice=int(input("Enter you chioce :"))
    if choice==1:
        string=input("Enter a Recipe Name:")
        ingredients.append(string)
        id_p=int(input("Enter a Recipe Description:"))
        ingredients.append(id_p)
             
    elif choice==2:
        id_p=int(input("Enter a Recipe id to update:"))
        Update_product.append(id_p)
        id_n=input("Enter a Recipe to update:")
        ingredientss.append(id_n)
        string=input("Enter a Recipe to update:")
        Update_product.append(string)        
        Quality=input("Enter a Recipe to Update:")
        ingredients.append(string)
        print("Updated Sucessfully!!")

# %%
#Question no 2
from pandas import*
from numpy import *
data={"Product_id":1,"Product Quality":"Good","Product Name":"PC","Avability":True,
         "Product_id":2,"Product Quality":"Median","Product Name":"Mouse","Avability":True,
         "Product_id":3,"Product Quality":"Bad","Product Name":"Keyboard","Avability":False,
          "Product_id":4,"Product Quality":"Good","Product Name":"Phone","Avability":True,
         }

list_product=[]
Update_product=[]
while True:
    print("\nPress 1 to Add new Product :")   
    print("Press 2 to Update Product :")
    print("Press 3 to check avability")
    choice=int(input("Enter you chioce :"))
    if choice==1:
        string=input("Enter a Product Name:")
        list_product.append(string)
        id_p=int(input("Enter a Product id:"))
        list_product.append(id_p)
        Quality=input("Enter a Product Quality:")
        list_product.append(string)      
    elif choice==2:
        id_p=int(input("Enter a Product id to update:"))
        Update_product.append(id_p)
        id_n=input("Enter a Product id to update:")
        Update_product.append(id_n)
        string=input("Enter a Product Name to update:")
        Update_product.append(string)        
        Quality=input("Enter a Product Quality to Update:")
        Update_product.append(string)
        print("Updated Sucessfully!!")
    elif choice==3:
            mask=id_p<=5
            print("Avalbility is:",mask)
# Out:
# Press 1 to Add new Product :
# Press 2 to Update Product :
# Press 3 to check avability
# Enter you chioce :1
# Enter a Product Name:Shoes
# Enter a Product id:5
# Enter a Product Quality:Bad
#
# Press 1 to Add new Product :
# Press 2 to Update Product :
# Press 3 to check avability
# Enter you chioce :3
# Avalbility is: True
#
# Press 1 to Add new Product :
# Press 2 to Update Product :
# Press 3 to check avability
# Enter you chioce :2
# Enter a Product id to update:5
# Enter a Product id to update:6
# Enter a Product Name to update:Bat
# Enter a Product Quality to Update:Good
# Updated Sucessfully!!
#
# Press 1 to Add new Product :
# Press 2 to Update Product :
# Press 3 to check avability

# %%
#Question no 3
from numpy import*
from pandas import*
matrix=random.randint(0,10,(3,3))
print("Random Matrix is: \n",matrix)
file=open("file.txt","w")
file.write(str(matrix))
file=open("file.txt","r")
array=file.read()
print("\nRandom Array after Reading from from text file :\n",array)
array_1d=matrix.reshape(1,9)
print("\nArray in a Single line :",array_1d)
count=0
for i in range(0,9):
    count+=1
size=count/2
print(" \nsize/2 of Array is:",int(size))
Majority=array_1d.max()
print("\nMajority Occurance of digit is",Majority)
not_majority=array_1d.min()
print("\nMinimum Occurance of digit is",not_majority)
sum_1=sum(array_1d[:5:])
sum_2=sum(array_1d[-5:5:])
if sum_1==sum_2:
    print("\nSum of left and right indexes are Equilrium")
    file=open("file.txt","w")
    file.write(str(sum_1))
    file.write(str(sum_2))
    
else:
    print("\nSum of left and right index are not Equilrium")
# Out:
# Random Matrix is:
#  [[7 7 6]
#  [8 6 6]
#  [1 8 9]]
#
# Random Array after Reading from from text file :
#  [[7 7 6]
#  [8 6 6]
#  [1 8 9]]
#
# Array in a Single line : [[7 7 6 8 6 6 1 8 9]]
#
# size/2 of Array is: 4
#
# Majority Occurance of digit is 9
#
# Minimum Occurance of digit is 1
#
# Sum of left and right indexes are Equilrium

# %%
#Question no 4 part 1
from pandas import*
from numpy import*
data=read_csv("dataset.csv")
df=DataFrame(data)
print("First five rows are :\n",df.head())
print("\nData Types are:\n",(df.dtypes))
print("\nMean of Age is:",df["Age"].mean())
print("Mean of Income is:",df["Income"].mean())
print("Mean of Height is:",df["Height"].mean())
print("Mean of Weight is:",df["Weight"].mean())
print("\nMedain of Income is:",df["Income"].median())
print("Medain of Height is:",df["Height"].mean())
print("Medain of Weight is:",df["Weight"].mean())
print("\nStandard Deviation of Age is:",df["Income"].mean())
print("Standard Deviation of Age is:",df["Height"].mean())
print("Standard of Weight is:",df["Weight"].mean())
df=df.dropna()
print("Data after Handling missing values:\n",df)
# Out:
# First five rows are :
#      Age    Education        Income      Height     Weight
# 0  56.0  High School  41672.007100  160.163603  78.691546
# 1  46.0          PhD  78217.356042         NaN  65.444605
# 2  32.0     Bachelor  28279.791494  166.277516  61.107592
# 3  60.0          PhD  17017.910651  169.152413        NaN
# 4  25.0  High School  56600.216751  191.154747  78.760468
#
# Data Types are:
#  Age          float64
# Education     object
# Income       float64
# Height       float64
# Weight       float64
# dtype: object
#
# Mean of Age is: 40.919213973799124
# Mean of Income is: 50979.73494293207
# Mean of Height is: 170.0576012203426
# Mean of Weight is: 69.71824319782034
#
# Medain of Income is: 50655.604387636726
# Medain of Height is: 170.0576012203426
# Medain of Weight is: 69.71824319782034
#
# Standard Deviation of Age is: 50979.73494293207
# Standard Deviation of Age is: 170.0576012203426
# Standard of Weight is: 69.71824319782034
# Data after Handling :
# ...

# %%
#Question 4 part 2
from pandas import*
from numpy import*
data=read_csv("dataset.csv")
df=DataFrame(data)
df=df["Education"].astype("category")
(df.dtypes)
# Out:
# CategoricalDtype(categories=['Bachelor', 'High School', 'Master', 'PhD'], ordered=False)

# %%
# Question 4 part 3
from pylab import*
from pandas import*
from numpy import*
data=read_csv("dataset.csv")
df=DataFrame(data)
fig=figure(figsize=(12,8))
fig,axes=subplots(2,2)
axes[0,0].hist(df["Age"],edgecolor=("black"),label="Age")
axes[0,0].hist(df["Weight"],edgecolor=("black"),label="Weight")
axes[0,0].set_xlabel("Height")
axes[0,0].set_ylabel("Income")
axes[0,0].set_title("Height vs Income")
axes[0,0].legend()
axes[0,1].hist(df["Income"],edgecolor=("black"),label="Income")
axes[0,1].hist(df["Weight"],edgecolor=("black"),label="Weight")
axes[0,1].set_xlabel("Weight")
axes[0,1].set_ylabel("Income")
axes[0,1].set_title("Weight vs Income")
axes[0,1].legend()
axes[1,0].hist(df["Height"],edgecolor=("black"),label="Income")
axes[1,0].hist(df["Weight"],edgecolor=("black"),label="Weight")
axes[1,0].set_xlabel("Height")
axes[1,0].set_ylabel("Weight")
axes[1,0].set_title("Weight vs Height")
axes[1,0].legend()
axes[1,1].hist(df["Income"],edgecolor=("black"),label="Income")
axes[1,1].hist(df["Height"],edgecolor=("black"),label="Income")
axes[1,1].hist(df["Weight"],edgecolor=("black"),label="Weight")
axes[1,1].set_xlabel("Height and Weight")
axes[1,1].set_ylabel("Income")
axes[1,1].set_title("Income vs Weight vs Height")
axes[1,1].legend()
tight_layout()
show()
df=df[df["Age"]>18]
print("Age Range greater than 18 are invovled:\n",df)
# Out:
# Age Range greater than 18 are invovled:
#        Age    Education        Income      Height     Weight
# 0    56.0  High School  41672.007100  160.163603  78.691546
# 1    46.0          PhD  78217.356042         NaN  65.444605
# 2    32.0     Bachelor  28279.791494  166.277516  61.107592
# 3    60.0          PhD  17017.910651  169.152413        NaN
# 4    25.0  High School  56600.216751  191.154747  78.760468
# ..    ...          ...           ...         ...        ...
# 995  22.0       Master  36209.231126  172.017923  66.636131
# 996  40.0       Master  12045.687159  169.070168        NaN
# 997  27.0          PhD           NaN  171.717705  74.624836
# 998  61.0       Master  66514.394525  182.624944  58.206309
# 999  19.0       Master  79375.211813  177.883597  71.722544
#
# [894 rows x 5 columns]
