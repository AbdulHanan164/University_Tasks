# %%
class Book:
    def __init__(self, title, author, isbn, year, price):
        self.title=title
        self.author=author
        self.isbn=isbn
        self.year=year
        self.price=price
    def __str__(self):
        return self.title+" is written by :"+self.author 
class LibraryCatalog:
    def __init__(self):
        self.books=[]
    def add_book(self, book):
        self.books.append(book)
    def remove_book(self, book):
        if book in self.books:
            self.books.remove(book)
        else:
            print("Book not Found")
    def __add__(self, other):
        Books=LibraryCatalog()
        for i in self.books+other.books:
            if i not in Books.books:
                Books.books.append(i)
        return Books
    def __sub__(self, other):
        Books = LibraryCatalog()
        for i in self.books:
            if i not in other.books:
                Books.books=i
            return Books
        return new_catalog
    def __eq__(self, other):
        if self.books==other.books:
            print("Equal Catalogies")
        else:
            print("Not Equal Catalogies")

    def __len__(self):
        return len(self.books)

    def __str__(self):
        return str(self.books)

# Create instances of the Book class
book1 = Book("Data Structures", "Dell Niles", "CS 2001", 2020, 15.99)
book2 = Book("Data Structures", "Dell Niles", "CS 2001", 2020, 15.99)
book3= Book("Programming for Ai", "Dr.Fayyaz", "Ai 1001", 2023, 32)
book4= Book("OOP", "Muiz", "CS 1001", 2022, 121)
book5= Book("Calculus", "Thomos", "MT 1001", 2019, 12.99)

# Create instances of the LibraryCatalog class
catalog1 = LibraryCatalog()
catalog2 = LibraryCatalog()
catalog4 = LibraryCatalog()
catalog43 = LibraryCatalog()
catalog5 = LibraryCatalog()
catalog55 = LibraryCatalog()
catalog7=LibraryCatalog()
# Add books to the catalogs
catalog1.add_book(["Data Structures", "Dell Niles", "CS 2001", 2020, 15.99])
catalog2.add_book(["Data Structures", "Dell Niles", "CS 2001", 2020, 15.99])
catalog43.add_book(["Programming for Ai", "Dr.Fayyaz", "Ai 1001", 2023, 32])
catalog5.add_book(["Calculus", "Thomos", "MT 1001", 2019, 12.99])
catalog55.add_book(["OOP", "Muiz", "CS 1001", 2022, 121])
#Remove book of the libraryCatalog class
catalog55.remove_book(["OOP", "Muiz", "CS 1001", 2022, 121])
print("Catalog 55 after removing:\n",catalog55)
# Demonstrate operator overloading for catalog addition
catalog3 = catalog1 + catalog2
if catalog1 == catalog2:
    print("Catalog 1 and Catalog 2 are equal.")
print("Catalog 1:\n",catalog1)
print("Catalog 2:\n",catalog2)
print("Catalog 3:\n",catalog3)
print("Number of books in Catalog 1:", len(catalog1))
print("Number of books in Catalog 2:", len(catalog2))
print("Number of books in Catalog 3:", len(catalog3))
catalog6=catalog43+catalog5
if catalog43==catalog5:
    print("Catalog 43 and 5 are equals.")
print("Catalog 43:\n",catalog43)
print("Catalog 5:\n",catalog5)
print("Catalog 6:\n",catalog6)
print("Number of books in Catalog 43:", len(catalog43))
print("Number of books in Catalog 5:", len(catalog5))
print("Number of books in Catalog 6:", len(catalog6))
catalog4 = catalog1 - catalog2
print("Catalog 4 after subtratcting same books:\n",catalog4)
catalog7=catalog43-catalog5
print("Catalog 7 after subtracting different books:\n",catalog7)
# Out:
# Catalog 55 after removing:
#  []
# Equal Catalogies
# Catalog 1:
#  [['Data Structures', 'Dell Niles', 'CS 2001', 2020, 15.99]]
# Catalog 2:
#  [['Data Structures', 'Dell Niles', 'CS 2001', 2020, 15.99]]
# Catalog 3:
#  [['Data Structures', 'Dell Niles', 'CS 2001', 2020, 15.99]]
# Number of books in Catalog 1: 1
# Number of books in Catalog 2: 1
# Number of books in Catalog 3: 1
# Not Equal Catalogies
# Catalog 43:
#  [['Programming for Ai', 'Dr.Fayyaz', 'Ai 1001', 2023, 32]]
# Catalog 5:
#  [['Calculus', 'Thomos', 'MT 1001', 2019, 12.99]]
# Catalog 6:
#  [['Programming for Ai', 'Dr.Fayyaz', 'Ai 1001', 2023, 32], ['Calculus', 'Thomos', 'MT 1001', 2019, 12.99]]
# Number of books in Catalog 43: 1
# Number of books in Catalog 5: 1
# Number of books in Catalog 6: 2
# Catalog 4 after subtratcting same books:
#  []
# Catalog 7 after subtracting different books:
#  ['Programming for Ai', 'Dr.Fayyaz', 'Ai 1001', 2023, 32]
